# %% [markdown]
# # How to download flights csv file from transtats website

# %% [markdown]
# **In this notebook, we will**
# 1. Download a csv file for each of your chosen year(s) and month(s)
# 2. Prepare the data for further processing
# 3. Push the prepared data to a table in the database

# %%
# Import all necessary libraries
import pandas as pd
import numpy as np
import psycopg2 # needed to get database exception errors when uploading dataframe
import requests # package for getting data from the web
from zipfile import * # package for unzipping zip files

# %%
# Import the get_engine function from our sql_functions.
from sql_functions import get_engine #adjust this as necessary to match your sql_functions.py connection methods

# %% [markdown]
# # 1. Download csv file with flight data for your specific year/month

# %% [markdown]
# In the following, you are going to download a csv file containing flight data from [this website](https://transtats.bts.gov).
# You can specify, which data you want to download.

# %% [markdown]
# Choose a month/year that you want to explore further.
# With the following functions, you will download a csv file on public flight data from [this website](https://transtats.bts.gov) containing data of your chosen month/year.
# The file will be stored in a data folder.
# Check out the url from which we download the data(https://transtats.bts.gov/PREZIP). Can we download data in this way from every source? What do you think?

# %%
# Specifies path for saving file
path ='data/' 
# Create the data folder
# !mkdir {path}
# Out:
# mkdir: data/: File exists

# %%
# function to get specified csv file from the website https://transtats.bts.gov

def download_data(year, month):
    # Get the file from the website https://transtats.bts.gov
    zip_file = f'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_{year}_{month}.zip'
    url = (f'https://transtats.bts.gov/PREZIP/{zip_file}')
    # Download the database
    r = requests.get(f'{url}', verify=False)
    # Save database to local file storage
    with open(path+zip_file, 'wb') as f:
        f.write(r.content)
        print(f'--> zip_file with name: {zip_file} downloaded succesfully.' )

# %%
# function to extract the csv files inside the zip files

def extract_zip(year, month):
    # Get the file from the website https://transtats.bts.gov
    zip_file = f'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_{year}_{month}.zip'
    with ZipFile(path+zip_file, 'r') as zip_ref:
        zip_ref.extractall(path)
        csv_file =  zip_ref.namelist()[0]
        print(f'--> zip_file was succesfully extracted to: {csv_file}.' )

# %% [markdown]
# Don't worry - the following download of the data you chose may take some time ...

# %%
years_list = [2010] # list of years you want to look at (can of course also be a single year)
months_list = [2] # list of months you want to look at (can of course also be a single month)

# download flights data as zipfile(s)
# we use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2010_2.zip downloaded succesfully.
# --> zip_file was succesfully extracted to: On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2010_2.csv.

# %% [markdown]
# Now it is time to load the csv files into dataframes. You can create your own function equivalent to the functions above. But you need to decide whether...
#
# - Do you need one dataframe for every month?
# - Would you like to proceed with only one dataframe containing all the data you downloaded?
# - One dataframe for every year?
#
# There are certain things to consider before.
# - changing column names
# - dealing with missing data
# - changing datatypes

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2010_2.csv'

# Read in your data
df = pd.read_csv(path+csv_file, low_memory = False)
display(df.shape)
display(df.head())
# Out:
# (483270, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2010        1      2           2          2  2010-02-02                WN
# 1  2010        1      2           2          2  2010-02-02                WN
# 2  2010        1      2           2          2  2010-02-02                WN
# 3  2010        1      2           2          2  2010-02-02                WN
# 4  2010        1      2           2          2  2010-02-02                WN
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19393                          WN      N907WN  ...
# 1                     19393                          WN      N270WN  ...
# 2                     19393                          WN      N357SW  ...
# 3                     19393                          WN      N918WN  ...
# 4                     19393                          WN      N355SW  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# # 2. Prepare the csv file for further processing

# %% [markdown]
# In the next step, we clean and prepare our dataset.

# %% [markdown]
# a) Since the dataset consists of a lot of columns, we we define which ones to keep.
# (Same as known from our SQL exercises on flights data.)

# %%
# Columns from downloaded file that are to be kept

columns_to_keep = [
                'FlightDate',
                'DepTime',
                'CRSDepTime',
                'DepDelay',
                'ArrTime',
                'CRSArrTime',
                'ArrDelay',
                'Reporting_Airline',
                'Tail_Number',
                'Flight_Number_Reporting_Airline',
                'Origin',
                'Dest',
                'AirTime',
                'ActualElapsedTime',
                'Distance',
                'Cancelled',
                'Diverted'
]

# %%
# The columns in the database have different naming as in the source csv files. Lets get the names from the database

schema = 'hh_analytics_24_1' # UPDATE 'TABLE_SCHEMA' based on schema used in class 
engine = get_engine() # assign engine to be able to query against the database

table_name_sql = f'''SELECT COLUMN_NAME 
                    FROM INFORMATION_SCHEMA.COLUMNS 
                    WHERE TABLE_NAME = 'flights'
                    AND TABLE_SCHEMA ='{schema}'
                    ORDER BY ordinal_position'''
c_names = engine.execute(table_name_sql).fetchall()
c_names
# Out:
# [('flight_date',),
#  ('dep_time',),
#  ('sched_dep_time',),
#  ('dep_delay',),
#  ('arr_time',),
#  ('sched_arr_time',),
#  ('arr_delay',),
#  ('airline',),
#  ('tail_number',),
#  ('flight_number',),
#  ('origin',),
#  ('dest',),
#  ('air_time',),
#  ('actual_elapsed_time',),
#  ('distance',),
#  ('cancelled',),
#  ('diverted',)]

# %%
# we can clean up the results into a clean list
new_column_names=[]
for name in c_names:
    new_column_names.append(name[0])
new_column_names
# Out:
# ['flight_date',
#  'dep_time',
#  'sched_dep_time',
#  'dep_delay',
#  'arr_time',
#  'sched_arr_time',
#  'arr_delay',
#  'airline',
#  'tail_number',
#  'flight_number',
#  'origin',
#  'dest',
#  'air_time',
#  'actual_elapsed_time',
#  'distance',
#  'cancelled',
#  'diverted']

# %%
# Just in case the above fails here are the results
'''new_column_names_alternate = ['flight_date', 'dep_time', 'sched_dep_time', 'dep_delay', 'arr_time', 'sched_arr_time', 
                'arr_delay', 'airline', 'tail_number', 'flight_number', 'origin', 'dest', 'air_time', 'actual_elapsed_time', 'distance', 'cancelled', 'diverted' ]'''
# Out:
# "new_column_names_alternate = ['flight_date', 'dep_time', 'sched_dep_time', 'dep_delay', 'arr_time', 'sched_arr_time', \n                'arr_delay', 'airline', 'tail_number', 'flight_number', 'origin', 'dest', 'air_time', 'actual_elapsed_time', 'distance', 'cancelled', 'diverted' ]"

# %% [markdown]
# b) With the next function, we make our csv file ready to be uploaded to SQL.
# We only keep to above specified columns and convert the datatypes.

# %%
def clean_airline_df(df):
    '''
    Transforms a df made from BTS csv file into a df that is ready to be uploaded to SQL
    Set rows=0 for no filtering
    '''

    # Build dataframe including only the columns you want to keep
    df_airline = df.loc[:,columns_to_keep]
     
    # Clean data types and NULLs
    df_airline['FlightDate']= pd.to_datetime(df_airline['FlightDate'], yearfirst=True)
    df_airline['CRSArrTime']= pd.to_numeric(df_airline['CRSArrTime'], downcast='integer', errors='coerce')
    df_airline['Cancelled']= pd.to_numeric(df_airline['Cancelled'], downcast='integer')
    df_airline['Diverted']= pd.to_numeric(df_airline['Diverted'], downcast='integer')
    df_airline['ActualElapsedTime']= pd.to_numeric(df_airline['ActualElapsedTime'], downcast='integer', errors='coerce')
    
    # Rename columns
    df_airline.columns = new_column_names
    
    return df_airline

# %%
# Call function and check resulting dataframe
df_clean = clean_airline_df(df)
df_clean.head()
# Out:
#   flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0  2010-02-02     830.0             830        0.0     842.0             900
# 1  2010-02-02    1129.0            1135       -6.0    1134.0            1200
# 2  2010-02-02    1424.0            1420        4.0    1443.0            1440
# 3  2010-02-02     625.0             635      -10.0     639.0             705
# 4  2010-02-02    1930.0            1820       70.0    1933.0            1845
#
#    arr_delay airline tail_number  flight_number origin dest  air_time  \
# 0      -18.0      WN      N907WN            334    CLE  MDW      60.0
# 1      -26.0      WN      N270WN            356    CLE  MDW      55.0
# 2        3.0      WN      N357SW            967    CLE  MDW      54.0
# 3      -26.0      WN      N918WN           1945    CLE  MDW      61.0
# 4       48.0      WN      N355SW           2624    CLE  MDW      51.0
#
#    actual_elapsed_time  distance  cancelled  diverted
# 0                 72.0     307.0          0         0
# 1                 65.0     307.0          0         0
# 2                 79.0     307.0          0         0
# 3                 74.0     307.0          0         0
# 4                 63.0     307.0          0         0

# %% [markdown]
# If you decide to only look at specific airports, it is a good decision to filter for them in advance.
# This function does the filtering.

# %%
# Specify the airports you are interested in and put them as a list in the function.
def select_airport(df, airports):
    ''' Helper function for filtering the airline dataframe for a subset of airports'''
    df_out = df.loc[(df.origin.isin(airports)) | (df.dest.isin(airports))]
    return df_out

# %%
# Execute function, filtering for New York area airports
airports=['DCA', 'IAD', 'BWI', 'PHL', 'EWR', 'JFK', 'LGA']
if len(airports) > 0:
    df_selected_airports = select_airport(df_clean, airports)
else:
    df_selected_airports = df_clean
    
df_selected_airports.head()
# Out:
#     flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 8    2010-02-02    1825.0            1830       -5.0    1926.0
# 9    2010-02-02    1047.0            1025       22.0    1153.0
# 10   2010-02-02    1331.0            1335       -4.0    1434.0
# 11   2010-02-02     638.0             630        8.0     749.0
# 176  2010-02-02     949.0             955       -6.0    1453.0
#
#      sched_arr_time  arr_delay airline tail_number  flight_number origin dest  \
# 8              1945      -19.0      WN      N257WN            484    CMH  BWI
# 9              1135       18.0      WN      N308SA            801    CMH  BWI
# 10             1445      -11.0      WN      N751SW           1480    CMH  BWI
# 11              740        9.0      WN      N942WN           3137    CMH  BWI
# 176            1515      -22.0      WN      N799SW            146    DEN  BWI
#
#      air_time  actual_elapsed_time  distance  cancelled  diverted
# 8        50.0                 61.0     336.0          0         0
# 9        52.0                 66.0     336.0          0         0
# 10       52.0                 63.0     336.0          0         0
# 11       50.0                 71.0     336.0          0         0
# 176     173.0                184.0    1491.0          0         0

# %%
type(airports)
# Out:
# list

# %%
df_selected_airports.isna().sum()
# Out:
# flight_date                0
# dep_time               14775
# sched_dep_time             0
# dep_delay              14775
# arr_time               14967
# sched_arr_time             0
# arr_delay              15141
# airline                    0
# tail_number             8176
# flight_number              0
# origin                     0
# dest                       0
# air_time               15141
# actual_elapsed_time    15141
# distance                   0
# cancelled                  0
# diverted                   0
# dtype: int64

# %%
df_selected_airports.flight_date.nunique()
# Out:
# 28

# %% [markdown]
# # 3. Push the prepared data to a table in the database

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
# Example: flights_sp for Sina's flights table, flights_groupname or similar
table_name = 'flights_api_sf'
# If the specified table doesn't exist yet, it will be created
# With 'replace', your data will be replaced if the table already exists.
# This may take some time ...

# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        df_selected_airports.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # Use schmea that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The flights_api_sf table was imported successfully.

# %%
from sql_functions import get_dataframe

# %%
schema = 'hh_analytics_24_1'

sql_query = f'SELECT * FROM {schema}.flights_group_x_sf'
flights = get_dataframe(sql_query)

flights.head(20)
# Out:
#    flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0   2010-02-02    1825.0            1830       -5.0    1926.0            1945
# 1   2010-02-02    1047.0            1025       22.0    1153.0            1135
# 2   2010-02-02    1331.0            1335       -4.0    1434.0            1445
# 3   2010-02-02     638.0             630        8.0     749.0             740
# 4   2010-02-02     949.0             955       -6.0    1453.0            1515
# 5   2010-02-02    1802.0            1805       -3.0    2320.0            2320
# 6   2010-02-02    1339.0            1345       -6.0    1841.0            1900
# 7   2010-02-02     908.0             910       -2.0    1424.0            1455
# 8   2010-02-02    1800.0            1805       -5.0    2318.0            2335
# 9   2010-02-02    1248.0            1245        3.0    1813.0            1830
# 10  2010-02-02    1632.0            1620       12.0    1803.0            1745
# 11  2010-02-02    1045.0            1030       15.0    1206.0            1200
# 12  2010-02-02     735.0             740       -5.0     853.0             910
# 13  2010-02-02    1431.0            1430        1.0    1653.0            1715
# 14  2010-02-02     734.0             735       -1.0     946.0            1010
# 15  2010-02-02    1736.0            1740       -4.0    2005.0            2015
# 16  2010-02-02    1107.0            1110       -3.0    1325.0            1345
# 17  2010-02-02     856.0             900       -4.0    1125.0            1150
# 18  2010-02-02    1333.0            1305       28.0    1556.0            1605
# 19  2010-02-02    1913.0            1845       28.0    2147.0            2130
#
#     arr_delay airline tail_number  flight_number  ... air_time  \
# 0       -19.0      WN      N257WN            484  ...     50.0
# 1        18.0      WN      N308SA            801  ...     52.0
# 2       -11.0      WN      N751SW           1480  ...     52.0
# 3         9.0      WN      N942WN           3137  ...     50.0
# 4       -22.0      WN      N799SW            146  ...    173.0
# 5         0.0      WN      N401WN            204  ...    175.0
# 6       -19.0      WN      N743SW            242  ...    170.0
# 7       -31.0      WN      N927WN           1305  ...    183.0
# 8       -17.0      WN      N225WN           2539  ...    181.0
# 9       -17.0      WN      N792SW           3397  ...    172.0
# 10       18.0      WN      N665WN            213  ...     65.0
# 11        6.0      WN      N370SW           1758  ...     63.0
# 12      -17.0      WN      N688SW           1922  ...     65.0
# 13      -22.0      WN      N386SW              9  ...    123.0
# 14      -24.0      WN      N451WN            214  ...    116.0
# 15      -10.0      WN      N688SW           1610  ...    127.0
# 16      -20.0      WN      N205WN           1942  ...    121.0
# 17      -25.0      WN      N503SW            644  ...    131.0
# 18       -9.0      WN      N629SW           2441  ...    126.0
# 19       17.0      WN      N383SW           3855  ...    138.0
#
#    actual_elapsed_time  distance  cancelled  diverted        lat         lon  \
# 0                 61.0     336.0          0         0  39.998001  -82.891899
# 1                 66.0     336.0          0         0  39.998001  -82.891899
# 2                 63.0     336.0          0         0  39.998001  -82.891899
# 3                 71.0     336.0          0         0  39.998001  -82.891899
# 4                184.0    1491.0          0         0  39.861698 -104.672997
# 5                198.0    1491.0          0         0  39.861698 -104.672997
# 6                182.0    1491.0          0         0  39.861698 -104.672997
# 7                196.0    1557.0          0         0  39.861698 -104.672997
# 8                198.0    1557.0          0         0  39.861698 -104.672997
# 9                205.0    1557.0          0         0  39.861698 -104.672997
# 10                91.0     408.0          0         0  42.212399  -83.353401
# 11                81.0     408.0          0         0  42.212399  -83.353401
# 12                78.0     408.0          0         0  42.212399  -83.353401
# 13               142.0     925.0          0         0  26.072599  -80.152702
# 14               132.0     925.0          0         0  26.072599  -80.152702
# 15               149.0     925.0          0         0  26.072599  -80.152702
# 16               138.0     925.0          0         0  26.072599  -80.152702
# 17               149.0     992.0          0         0  26.072599  -80.152702
# 18               143.0     992.0          0         0  26.072599  -80.152702
# 19               154.0     992.0          0         0  26.072599  -80.152702
#
#                city  tz_origin tz_dest
# 0          Columbus       -5.0    -5.0
# 1          Columbus       -5.0    -5.0
# 2          Columbus       -5.0    -5.0
# 3          Columbus       -5.0    -5.0
# 4            Denver       -7.0    -5.0
# 5            Denver       -7.0    -5.0
# 6            Denver       -7.0    -5.0
# 7            Denver       -7.0    -5.0
# 8            Denver       -7.0    -5.0
# 9            Denver       -7.0    -5.0
# 10          Detroit       -5.0    -5.0
# 11          Detroit       -5.0    -5.0
# 12          Detroit       -5.0    -5.0
# 13  Fort Lauderdale       -5.0    -5.0
# 14  Fort Lauderdale       -5.0    -5.0
# 15  Fort Lauderdale       -5.0    -5.0
# 16  Fort Lauderdale       -5.0    -5.0
# 17  Fort Lauderdale       -5.0    -5.0
# 18  Fort Lauderdale       -5.0    -5.0
# 19  Fort Lauderdale       -5.0    -5.0
#
# [20 rows x 22 columns]

# %%
flights[['cancelled', 'diverted', 'flight_date']].groupby('flight_date').sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 flights[['cancelled', 'diverted', 'flight_date']].groupby('flight_date').sum()
#
# NameError: name 'flights' is not defined

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming df is your DataFrame containing flight_date, cancelled, and diverted columns

# Convert flight_date to datetime if it's not already in datetime format
flights['flight_date'] = pd.to_datetime(flights['flight_date'])

# Group by flight_date and aggregate counts of cancelled and diverted flights
agg_flights = flights.groupby('flight_date').agg({'cancelled': 'sum', 'diverted': 'sum'}).reset_index()

# Plot the counts
plt.figure(figsize=(10, 6))
plt.plot(agg_flights['flight_date'], agg_flights['cancelled'], label='Cancelled Flights', marker='o')
plt.plot(agg_flights['flight_date'], agg_flights['diverted'], label='Diverted Flights', marker='o')

# Add labels and title
plt.xlabel('Flight Date')
plt.ylabel('Count')
plt.title('Count of Cancelled and Diverted Flights by Flight Date')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.show()

# %%
# Just to be sure: Check if the number of rows match
table_name_sql = f'SELECT count(*) 
                    FROM {schema}.{table_name}
                    '
engine.execute(table_name_sql).fetchall()[0][0] == df_selected_airports.shape[0]
# Out:
#   Cell In[59], line 2
#     table_name_sql = f'SELECT count(*)
#                                        ^
# SyntaxError: EOL while scanning string literal

# %%
from sql_functions import get_dataframe

# %%
schema = 'hh_analytics_24_1'

sql_query = f'SELECT * FROM {schema}.weather_stacked_groupx'
weather_stacked = get_dataframe(sql_query)

weather_stacked.head(20)
# Out:
#           date  tavg  tmin  tmax  prcp   snow   wdir  wspd  wpgt    pres  \
# 0   2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 1   2010-02-02  -1.0  -3.9   0.6   0.0    0.0    NaN  10.1  None  1023.8
# 2   2010-02-03   0.3  -2.2   4.4   0.8   25.0    NaN  15.8  None  1018.1
# 3   2010-02-04   0.8  -1.7   3.3   0.0    0.0  317.0  22.3  None  1025.8
# 4   2010-02-05   0.6  -1.7   2.8   0.0    0.0    NaN  11.5  None  1023.3
# 5   2010-02-06  -3.1  -6.1   0.6   2.8    0.0   36.0  33.1  None  1008.1
# 6   2010-02-07  -4.2  -8.9   1.7   0.0   25.0  330.0  28.1  None  1011.3
# 7   2010-02-08  -1.2  -5.0   3.9   0.0    0.0  305.0  27.7  None  1014.3
# 8   2010-02-09   0.8  -2.2   4.4   0.5    0.0  263.0  15.1  None  1015.9
# 9   2010-02-10  -0.2  -1.1   0.6  31.5   51.0    NaN  31.3  None   992.7
# 10  2010-02-11   0.2  -2.2   2.8   0.0  254.0  321.0  32.0  None  1000.6
# 11  2010-02-12  -0.9  -3.9   2.2   0.0  229.0  314.0  22.0  None  1009.4
# 12  2010-02-13  -2.3  -4.4   0.0   0.0  203.0  323.0  25.2  None     NaN
# 13  2010-02-14   0.1  -2.8   3.9   0.0  203.0  284.0  28.4  None  1002.2
# 14  2010-02-15  -0.1  -2.8   2.8   2.0  152.0    NaN  20.9  None  1007.9
# 15  2010-02-01  -4.5 -14.4   3.3   0.0   51.0    NaN   6.1  None  1026.4
# 16  2010-02-02  -1.6  -9.4   4.4   7.1   25.0    NaN   3.2  None     NaN
# 17  2010-02-03   1.2  -2.8   4.4   0.5  102.0    NaN   8.3  None  1020.2
# 18  2010-02-04   1.3  -2.8   4.4   0.0   51.0    NaN   7.6  None  1028.7
# 19  2010-02-05   0.1  -1.1   1.7  37.3   25.0    NaN   9.7  None     NaN
#
#     tsun station_id  faa
# 0   None      74486  JFK
# 1   None      74486  JFK
# 2   None      74486  JFK
# 3   None      74486  JFK
# 4   None      74486  JFK
# 5   None      74486  JFK
# 6   None      74486  JFK
# 7   None      74486  JFK
# 8   None      74486  JFK
# 9   None      74486  JFK
# 10  None      74486  JFK
# 11  None      74486  JFK
# 12  None      74486  JFK
# 13  None      74486  JFK
# 14  None      74486  JFK
# 15  None      72403  IAD
# 16  None      72403  IAD
# 17  None      72403  IAD
# 18  None      72403  IAD
# 19  None      72403  IAD

# %%
schema = 'hh_analytics_24_1'

sql_query = f'SELECT * FROM {schema}.flights_group_x'
flights_x = get_dataframe(sql_query)

# %%
import pandas as pd


merged_df = weather_stacked.merge(flights_x, how='left', left_on='faa', right_on='origin')

# Display the merged DataFrame
print(merged_df)
# Out:
#               date  tavg  tmin  tmax  prcp   snow   wdir  wspd  wpgt    pres  \
# 0       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 1       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 2       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 3       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 4       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# ...            ...   ...   ...   ...   ...    ...    ...   ...   ...     ...
# 146710  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146711  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146712  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146713  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146714  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
#
#         ... air_time actual_elapsed_time distance cancelled  diverted  \
# 0       ...      NaN                 NaN    740.0         1         0
# 1       ...     48.0                70.0    228.0         0         0
# 2       ...     55.0                75.0    228.0         0         0
# 3       ...     53.0                71.0    228.0         0         0
# 4       ...     45.0                72.0    228.0         0         0
# ...     ...      ...                 ...      ...       ...       ...
# 146710  ...     25.0                44.0     96.0         0         0
# 146711  ...      NaN                 NaN     96.0         1         0
# 146712  ...     33.0                80.0     96.0         0         0
# 146713  ...     28.0                46.0     96.0         0         0
# 146714  ...     30.0                77.0     96.0         0         0
#
#               lat        lon          city  tz_origin  tz_dest
# 0       40.639801 -73.778900      New York       -5.0     -6.0
# 1       40.639801 -73.778900      New York       -5.0     -5.0
# 2       40.639801 -73.778900      New York       -5.0     -5.0
# 3       40.639801 -73.778900      New York       -5.0     -5.0
# 4       40.639801 -73.778900      New York       -5.0     -5.0
# ...           ...        ...           ...        ...      ...
# 146710  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146711  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146712  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146713  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146714  39.871899 -75.241096  Philadelphia       -5.0     -5.0
#
# [146715 rows x 35 columns]

# %%
import pandas as pd

# Assuming 'flights' is your DataFrame containing flight data

# Calculate cancellation rate per day
cancellation_rate_per_day = merged_df.groupby('flight_date')['cancelled'].mean()
print(cancellation_rate_per_day)

# Calculate the average cancellation rate per day
average_cancellation_rate_per_day = cancellation_rate_per_day.mean()

##print("Average cancellation rate per day:", average_cancellation_rate_per_day)
# Out:
# flight_date
# 2010-02-01    0.000000
# 2010-02-02    0.015244
# 2010-02-03    0.000000
# 2010-02-04    0.000000
# 2010-02-05    0.110482
# 2010-02-06    0.313916
# 2010-02-07    0.127907
# 2010-02-08    0.043228
# 2010-02-09    0.134146
# 2010-02-10    0.908824
# 2010-02-11    0.256831
# 2010-02-12    0.016393
# 2010-02-13    0.009174
# 2010-02-14    0.002841
# 2010-02-15    0.011111
# 2010-02-16    0.106443
# 2010-02-17    0.016713
# 2010-02-18    0.000000
# 2010-02-19    0.002732
# 2010-02-20    0.009119
# 2010-02-21    0.000000
# 2010-02-22    0.013812
# 2010-02-23    0.022409
# 2010-02-24    0.016807
# 2010-02-25    0.275956
# 2010-02-26    0.568306
# 2010-02-27    0.090634
# 2010-02-28    0.000000
# Name: cancelled, dtype: float64

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146715 entries, 0 to 146714
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 146715 non-null  object
#  1   tavg                 146715 non-null  float64
#  2   tmin                 146715 non-null  float64
#  3   tmax                 146715 non-null  float64
#  4   prcp                 146715 non-null  float64
#  5   snow                 146715 non-null  float64
#  6   wdir                 92042 non-null   float64
#  7   wspd                 146715 non-null  float64
#  8   wpgt                 0 non-null       object
#  9   pres                 132590 non-null  float64
#  10  tsun                 0 non-null       object
#  11  station_id           146715 non-null  object
#  12  faa                  146715 non-null  object
#  13  flight_date          146715 non-null  datetime64[ns]
#  14  dep_time             130920 non-null  float64
#  15  sched_dep_time       146715 non-null  int64
#  16  dep_delay            130920 non-null  float64
#  17  arr_time             130680 non-null  float64
#  18  sched_arr_time       146715 non-null  int64
#  19  arr_delay            130290 non-null  float64
#  20  airline              146715 non-null  object
#  21  tail_number          140280 non-null  object
#  22  flight_number        146715 non-null  int64
#  23  origin               146715 non-null  object
#  24  dest                 146715 non-null  object
#  25  air_time             130290 non-null  float64
#  26  actual_elapsed_time  130290 non-null  float64
#  27  distance             146715 non-null  float64
#  28  cancelled            146715 non-null  int64
#  29  diverted             146715 non-null  int64
#  30  lat                  146715 non-null  float64
#  31  lon                  146715 non-null  float64
#  32  city                 146715 non-null  object
#  33  tz_origin            146715 non-null  float64
#  34  tz_dest              146715 non-null  float64
# dtypes: datetime64[ns](1), float64(19), int64(5), object(10)
# memory usage: 40.3+ MB

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.plot(cancellation_rate_per_day.index, cancellation_rate_per_day.values, marker='o', linestyle='-')
plt.xlabel('Flight Date')
plt.ylabel('Cancellation Rate')
plt.title('Cancellation Rate per Day')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
average_cancellation_rate_per_day = cancellation_rate_per_day.mean()

plt.figure(figsize=(10, 6))
plt.plot(cancellation_rate_per_day.index, cancellation_rate_per_day.values, marker='o', linestyle='-', label='Cancellation Rate per Day')
plt.axhline(y=average_cancellation_rate_per_day, color='r', linestyle='--', label='Average Cancellation Rate')
plt.xlabel('Flight Date')
plt.ylabel('Cancellation Rate')
plt.title('Cancellation Rate per Day')
plt.grid(True)
plt.xticks(rotation=45)
plt.legend()
plt.tight_layout()
plt.show()

# %%
merged_df.cancelled.mean()
# Out:
# 0.10908905019936611

# %%
merged_df.cancelled.count()
# Out:
# 146715

# %%
snow_cancellation_rate_per_day = merged_df.groupby('flight_date').agg({
    'cancelled': 'mean',
    'snow': 'sum'  # Assuming 'snow' column contains the amount of snow for each flight
})
print(snow_cancellation_rate_per_day)
# Out:
#              cancelled      snow
# flight_date
# 2010-02-01    0.000000  543052.0
# 2010-02-02    0.015244  496358.0
# 2010-02-03    0.000000  517590.0
# 2010-02-04    0.000000  545336.0
# 2010-02-05    0.110482  541572.0
# 2010-02-06    0.313916  457996.0
# 2010-02-07    0.127907  506298.0
# 2010-02-08    0.043228  543052.0
# 2010-02-09    0.134146  496358.0
# 2010-02-10    0.908824  526726.0
# 2010-02-11    0.256831  556418.0
# 2010-02-12    0.016393  556418.0
# 2010-02-13    0.009174  461888.0
# 2010-02-14    0.002841  523766.0
# 2010-02-15    0.011111  549566.0
# 2010-02-16    0.106443  537808.0
# 2010-02-17    0.016713  540092.0
# 2010-02-18    0.000000  555276.0
# 2010-02-19    0.002732  556418.0
# 2010-02-20    0.009119  464172.0
# 2010-02-21    0.000000  531760.0
# 2010-02-22    0.013812  551850.0
# 2010-02-23    0.022409  537808.0
# 2010-02-24    0.016807  537808.0
# 2010-02-25    0.275956  556418.0
# 2010-02-26    0.568306  556418.0
# 2010-02-27    0.090634  466456.0
# 2010-02-28    0.000000  531760.0

# %%
import matplotlib.pyplot as plt

# Assuming snow_cancellation_rate_per_day is your DataFrame containing cancellation rate and snow data per day

# Plot the cancellation rate per day
plt.figure(figsize=(10, 6))
plt.plot(snow_cancellation_rate_per_day.index, snow_cancellation_rate_per_day['cancelled'], marker='o', linestyle='-', label='Cancellation Rate')
plt.xlabel('Flight Date')
plt.ylabel('Cancellation Rate')
plt.title('Cancellation Rate and Snow per Day')
plt.grid(True)

# Plot the total amount of snow per day
plt.twinx()  # Create a second y-axis
plt.plot(snow_cancellation_rate_per_day.index, snow_cancellation_rate_per_day['snow'], marker='s', linestyle='--', color='r', label='Snow')
plt.ylabel('Snow Amount')
plt.grid(False)

# Show legend
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
windspeed_cancellation_rate_per_day = merged_df.groupby('flight_date').agg({
    'cancelled': 'mean',
    'wspd': 'sum'  # Assuming 'snow' column contains the amount of snow for each flight
})
print(windspeed_cancellation_rate_per_day)
# Out:
#              cancelled      wspd
# flight_date
# 2010-02-01    0.000000  114506.8
# 2010-02-02    0.015244  108870.8
# 2010-02-03    0.000000  109631.2
# 2010-02-04    0.000000  115198.4
# 2010-02-05    0.110482  116893.0
# 2010-02-06    0.313916  102923.4
# 2010-02-07    0.127907  114715.0
# 2010-02-08    0.043228  114506.8
# 2010-02-09    0.134146  108870.8
# 2010-02-10    0.908824  112397.6
# 2010-02-11    0.256831  121388.4
# 2010-02-12    0.016393  121388.4
# 2010-02-13    0.009174  109770.6
# 2010-02-14    0.002841  117170.0
# 2010-02-15    0.011111  119313.6
# 2010-02-16    0.106443  118587.6
# 2010-02-17    0.016713  119279.2
# 2010-02-18    0.000000  121042.6
# 2010-02-19    0.002732  121388.4
# 2010-02-20    0.009119  110462.2
# 2010-02-21    0.000000  119590.6
# 2010-02-22    0.013812  120005.2
# 2010-02-23    0.022409  118587.6
# 2010-02-24    0.016807  118587.6
# 2010-02-25    0.275956  121388.4
# 2010-02-26    0.568306  121388.4
# 2010-02-27    0.090634  111153.8
# 2010-02-28    0.000000  119590.6

# %%
import matplotlib.pyplot as plt

# Assuming windspeed_cancellation_rate_per_day is your DataFrame containing cancellation rate and wind speed data per day

# Plot the cancellation rate per day
plt.figure(figsize=(10, 6))
plt.plot(windspeed_cancellation_rate_per_day.index, windspeed_cancellation_rate_per_day['cancelled'], marker='o', linestyle='-', label='Cancellation Rate')
plt.xlabel('Flight Date')
plt.ylabel('Cancellation Rate')
plt.title('Cancellation Rate and Wind Speed per Day')
plt.grid(True)

# Plot the total wind speed per day
plt.twinx()  # Create a second y-axis
plt.plot(windspeed_cancellation_rate_per_day.index, windspeed_cancellation_rate_per_day['wspd'], marker='s', linestyle='--', color='r', label='Wind Speed')
plt.ylabel('Wind Speed')
plt.grid(False)

# Show legend
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
temp_cancellation_rate_per_day = merged_df.groupby('flight_date').agg({
    'cancelled': 'mean',
    'tavg': 'mean'  # Assuming 'snow' column contains the amount of snow for each flight
})
print(temp_cancellation_rate_per_day)
# Out:
#              cancelled      tavg
# flight_date
# 2010-02-01    0.000000 -0.887358
# 2010-02-02    0.015244 -0.869065
# 2010-02-03    0.000000 -0.885181
# 2010-02-04    0.000000 -0.886514
# 2010-02-05    0.110482 -0.876544
# 2010-02-06    0.313916 -0.858015
# 2010-02-07    0.127907 -0.854535
# 2010-02-08    0.043228 -0.887358
# 2010-02-09    0.134146 -0.869065
# 2010-02-10    0.908824 -0.881765
# 2010-02-11    0.256831 -0.871694
# 2010-02-12    0.016393 -0.871694
# 2010-02-13    0.009174 -0.833578
# 2010-02-14    0.002841 -0.860265
# 2010-02-15    0.011111 -0.873889
# 2010-02-16    0.106443 -0.866797
# 2010-02-17    0.016713 -0.866091
# 2010-02-18    0.000000 -0.872055
# 2010-02-19    0.002732 -0.871694
# 2010-02-20    0.009119 -0.833009
# 2010-02-21    0.000000 -0.857920
# 2010-02-22    0.013812 -0.873149
# 2010-02-23    0.022409 -0.866797
# 2010-02-24    0.016807 -0.866797
# 2010-02-25    0.275956 -0.871694
# 2010-02-26    0.568306 -0.871694
# 2010-02-27    0.090634 -0.832447
# 2010-02-28    0.000000 -0.857920

# %%
import matplotlib.pyplot as plt

# Assuming temp_cancellation_rate_per_day is your DataFrame containing cancellation rate and average temperature data per day

# Plot the cancellation rate per day
plt.figure(figsize=(10, 6))
plt.plot(temp_cancellation_rate_per_day.index, temp_cancellation_rate_per_day['cancelled'], marker='o', linestyle='-', label='Cancellation Rate')
plt.xlabel('Flight Date')
plt.ylabel('Cancellation Rate')
plt.title('Cancellation Rate and Average Temperature per Day')
plt.grid(True)

# Plot the average temperature per day
plt.twinx()  # Create a second y-axis
plt.plot(temp_cancellation_rate_per_day.index, temp_cancellation_rate_per_day['tavg'], marker='s', linestyle='--', color='r', label='Average Temperature')
plt.ylabel('Average Temperature')
plt.grid(False)

# Show legend
plt.legend(loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
from scipy import stats

# %%
from scipy.stats import spearmanr

r, p = spearmanr(merged_df['snow'], merged_df['cancelled'])

print('Correlation coefficient:', r)
print('p-value:', p)
# Out:
# Correlation coefficient: 0.04276718177388597
# p-value: 2.3054332629047272e-60

# %%
# Calculate Spearman correlation coefficient and p-value
r, p = spearmanr(merged_df['wspd'], merged_df['cancelled'])

print('Correlation coefficient:', r)
print('p-value:', p)
# Out:
# Correlation coefficient: -0.03669560507901607
# p-value: 6.662433844293686e-45

# %%
df = merged_df[['flight_date', 'faa', 'tavg', 'tmin', 'tmax', 'prcp', 'snow', 'wspd', 'cancelled']]

# %%
from scipy.stats import spearmanr

r, p = spearmanr(df['snow'], df['cancelled'])

print('Correlation coefficient:', r)
print('p-value:', p)
# Out:
# Correlation coefficient: 0.04276718177388597
# p-value: 2.3054332629047272e-60

# %%
merged_df.info().tail(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 146715 entries, 0 to 146714
# Data columns (total 35 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   date                 146715 non-null  object
#  1   tavg                 146715 non-null  float64
#  2   tmin                 146715 non-null  float64
#  3   tmax                 146715 non-null  float64
#  4   prcp                 146715 non-null  float64
#  5   snow                 146715 non-null  float64
#  6   wdir                 92042 non-null   float64
#  7   wspd                 146715 non-null  float64
#  8   wpgt                 0 non-null       object
#  9   pres                 132590 non-null  float64
#  10  tsun                 0 non-null       object
#  11  station_id           146715 non-null  object
#  12  faa                  146715 non-null  object
#  13  flight_date          146715 non-null  datetime64[ns]
#  14  dep_time             130920 non-null  float64
#  15  sched_dep_time       146715 non-null  int64
#  16  dep_delay            130920 non-null  float64
#  17  arr_time             130680 non-null  float64
#  18  sched_arr_time       146715 non-null  int64
#  19  arr_delay            130290 non-null  float64
#  20  airline              146715 non-null  object
#  21  tail_number          140280 non-null  object
#  22  flight_number        146715 non-null  int64
#  23  origin               146715 non-null  object
#  24  dest                 146715 non-null  object
#  25  air_time             130290 non-null  float64
#  26  actual_elapsed_time  130290 non-null  float64
#  27  distance             146715 non-null  float64
#  28  cancelled            146715 non-null  int64
#  29  diverted             146715 non-null  int64
#  30  lat                  146715 non-null  float64
#  31  lon                  146715 non-null  float64
#  32  city                 146715 non-null  object
#  33  tz_origin            146715 non-null  float64
#  34  tz_dest              146715 non-null  float64
# dtypes: datetime64[ns](1), float64(19), int64(5), object(10)
# memory usage: 40.3+ MB
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 merged_df.info().tail(10)
#
# AttributeError: 'NoneType' object has no attribute 'tail'

# %%
merged_df.date.describe()
# Out:
# count         146715
# unique            15
# top       2010-02-01
# freq            9781
# Name: date, dtype: object

# %%
type(merged_df)
# Out:
# pandas.core.frame.DataFrame

# %%
merged_df.snow.describe()
# Out:
# count    146715.000000
# mean        100.510773
# std         137.809697
# min           0.000000
# 25%           0.000000
# 50%          25.000000
# 75%         203.000000
# max         660.000000
# Name: snow, dtype: float64

# %%
merged_df.cancelled.info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 146715 entries, 0 to 146714
# Series name: cancelled
# Non-Null Count   Dtype
# --------------   -----
# 146715 non-null  int64
# dtypes: int64(1)
# memory usage: 2.2 MB

# %%
flights_x.head()
# Out:
#   flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0  2010-02-02     727.0             730       -3.0     835.0             855
# 1  2010-02-02    1536.0            1540       -4.0    1646.0            1710
# 2  2010-02-02    1239.0            1130       69.0    1338.0            1255
# 3  2010-02-02    1355.0            1355        0.0    1514.0            1550
# 4  2010-02-02    1026.0            1030       -4.0    1145.0            1225
#
#    arr_delay airline tail_number  flight_number  ... air_time  \
# 0      -20.0      WN      N798SW             61  ...     43.0
# 1      -24.0      WN      N210WN             65  ...     40.0
# 2       43.0      WN      N207WN           2064  ...     42.0
# 3      -36.0      WN      N456WN            232  ...    111.0
# 4      -40.0      WN      N227WN           1510  ...    116.0
#
#   actual_elapsed_time  distance  cancelled  diverted        lat        lon  \
# 0                68.0     185.0          0         0  40.777199 -73.872597
# 1                70.0     185.0          0         0  40.777199 -73.872597
# 2                59.0     185.0          0         0  40.777199 -73.872597
# 3               139.0     725.0          0         0  40.777199 -73.872597
# 4               139.0     725.0          0         0  40.777199 -73.872597
#
#        city  tz_origin tz_dest
# 0  New York       -5.0    -5.0
# 1  New York       -5.0    -5.0
# 2  New York       -5.0    -5.0
# 3  New York       -5.0    -6.0
# 4  New York       -5.0    -6.0
#
# [5 rows x 22 columns]

# %%
weather_stacked.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        60 non-null     object
#  1   tavg        60 non-null     float64
#  2   tmin        60 non-null     float64
#  3   tmax        60 non-null     float64
#  4   prcp        60 non-null     float64
#  5   snow        60 non-null     float64
#  6   wdir        26 non-null     float64
#  7   wspd        60 non-null     float64
#  8   wpgt        0 non-null      object
#  9   pres        42 non-null     float64
#  10  tsun        0 non-null      object
#  11  station_id  60 non-null     object
#  12  faa         60 non-null     object
# dtypes: float64(8), object(5)
# memory usage: 6.2+ KB

# %%
weather_stacked.faa.unique()
# Out:
# array(['JFK', 'IAD', 'PHL'], dtype=object)

# %%
merged_df.isna().sum()
# Out:
# date                        0
# tavg                        0
# tmin                        0
# tmax                        0
# prcp                        0
# snow                        0
# wdir                    54673
# wspd                        0
# wpgt                   146715
# pres                    14125
# tsun                   146715
# station_id                  0
# faa                         0
# flight_date                 0
# dep_time                15795
# sched_dep_time              0
# dep_delay               15795
# arr_time                16035
# sched_arr_time              0
# arr_delay               16425
# airline                     0
# tail_number              6435
# flight_number               0
# origin                      0
# dest                        0
# air_time                16425
# actual_elapsed_time     16425
# distance                    0
# cancelled                   0
# diverted                    0
# lat                         0
# lon                         0
# city                        0
# tz_origin                   0
# tz_dest                     0
# dtype: int64

# %%
merged_df.duplicated
# Out:
# <bound method DataFrame.duplicated of               date  tavg  tmin  tmax  prcp   snow   wdir  wspd  wpgt    pres  \
# 0       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 1       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 2       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 3       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# 4       2010-02-01  -0.9  -3.9   2.8   0.0    0.0  270.0  22.3  None  1023.4
# ...            ...   ...   ...   ...   ...    ...    ...   ...   ...     ...
# 146710  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146711  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146712  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146713  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
# 146714  2010-02-15  -1.3  -6.1   2.8   2.3  254.0    NaN  11.9  None     NaN
#
#         ... air_time actual_elapsed_time distance cancelled  diverted  \
# 0       ...      NaN                 NaN    740.0         1         0
# 1       ...     48.0                70.0    228.0         0         0
# 2       ...     55.0                75.0    228.0         0         0
# 3       ...     53.0                71.0    228.0         0         0
# 4       ...     45.0                72.0    228.0         0         0
# ...     ...      ...                 ...      ...       ...       ...
# 146710  ...     25.0                44.0     96.0         0         0
# 146711  ...      NaN                 NaN     96.0         1         0
# 146712  ...     33.0                80.0     96.0         0         0
# 146713  ...     28.0                46.0     96.0         0         0
# 146714  ...     30.0                77.0     96.0         0         0
#
#               lat        lon          city  tz_origin  tz_dest
# 0       40.639801 -73.778900      New York       -5.0     -6.0
# 1       40.639801 -73.778900      New York       -5.0     -5.0
# 2       40.639801 -73.778900      New York       -5.0     -5.0
# 3       40.639801 -73.778900      New York       -5.0     -5.0
# 4       40.639801 -73.778900      New York       -5.0     -5.0
# ...           ...        ...           ...        ...      ...
# 146710  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146711  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146712  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146713  39.871899 -75.241096  Philadelphia       -5.0     -5.0
# 146714  39.871899 -75.241096  Philadelphia       -5.0     -5.0
#
# [146715 rows x 35 columns]>
