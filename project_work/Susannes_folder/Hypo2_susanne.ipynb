# %% [markdown]
# # 1. DATA CLEANSING - Getting ready for testing hypothesis 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sql_functions import get_dataframe

# %%
# Floats (decimal numbers) should be displayed rounded with 2 decimal places
pd.options.display.float_format = "{:,.2f}".format
# Set style for plots
plt.style.use('fivethirtyeight')

# %%
schema = 'hh_analytics_24_1'

#sql_query to retrieve the data from DBeaver and saving it as a df
sql_query = f'SELECT * FROM {schema}.weather_stacked_groupx'
weather_stacked_sf = get_dataframe(sql_query)

weather_stacked_sf
# Out:
#           date  tavg   tmin  tmax  prcp   snow   wdir  wspd  wpgt     pres  \
# 0   2010-02-01 -0.90  -3.90  2.80  0.00   0.00 270.00 22.30  None 1,023.40
# 1   2010-02-02 -1.00  -3.90  0.60  0.00   0.00    NaN 10.10  None 1,023.80
# 2   2010-02-03  0.30  -2.20  4.40  0.80  25.00    NaN 15.80  None 1,018.10
# 3   2010-02-04  0.80  -1.70  3.30  0.00   0.00 317.00 22.30  None 1,025.80
# 4   2010-02-05  0.60  -1.70  2.80  0.00   0.00    NaN 11.50  None 1,023.30
# 5   2010-02-06 -3.10  -6.10  0.60  2.80   0.00  36.00 33.10  None 1,008.10
# 6   2010-02-07 -4.20  -8.90  1.70  0.00  25.00 330.00 28.10  None 1,011.30
# 7   2010-02-08 -1.20  -5.00  3.90  0.00   0.00 305.00 27.70  None 1,014.30
# 8   2010-02-09  0.80  -2.20  4.40  0.50   0.00 263.00 15.10  None 1,015.90
# 9   2010-02-10 -0.20  -1.10  0.60 31.50  51.00    NaN 31.30  None   992.70
# 10  2010-02-11  0.20  -2.20  2.80  0.00 254.00 321.00 32.00  None 1,000.60
# 11  2010-02-12 -0.90  -3.90  2.20  0.00 229.00 314.00 22.00  None 1,009.40
# 12  2010-02-13 -2.30  -4.40  0.00  0.00 203.00 323.00 25.20  None      NaN
# 13  2010-02-14  0.10  -2.80  3.90  0.00 203.00 284.00 28.40  None 1,002.20
# 14  2010-02-15 -0.10  -2.80  2.80  2.00 152.00    NaN 20.90  None 1,007.90
# 15  2010-02-01 -4.50 -14.40  3.30  0.00  51.00    NaN  6.10  None 1,026.40
# 16  2010-02-02 -1.60  -9.40  4.40  7.10  25.00    NaN  3.20  None      NaN
# 17  2010-02-03  1.20  -2.80  4.40  0.50 102.00    NaN  8.30  None 1,020.20
# 18  2010-02-04  1.30  -2.80  4.40  0.00  51.00    NaN  7.60  None 1,028.70
# 19  2010-02-05  0.10  -1.10  1.70 37.30  25.00    NaN  9.70  None      NaN
# 20  2010-02-06 -2.90 -12.20  0.00 50.30 457.00    NaN 16.90  None      NaN
# 21  2010-02-07 -6.10 -13.90 -0.60  0.00 533.00    NaN 12.60  None 1,016.50
# 22  2010-02-08 -5.00 -10.60  0.00  0.00 508.00    NaN 11.90  None 1,021.00
# 23  2010-02-09 -4.60 -12.20  1.70  7.60 483.00    NaN  3.20  None      NaN
# 24  2010-02-10 -3.60  -6.70 -1.10 10.70 660.00 321.00 31.00  None      NaN
# 25  2010-02-11  0.10  -2.20  3.30  0.00 635.00 306.00 25.60  None 1,009.20
# 26  2010-02-12 -1.00  -5.00  2.80  0.00 508.00    NaN 13.00  None 1,013.30
# 27  2010-02-13 -1.80  -3.30  0.00  0.00 457.00 315.00 20.50  None 1,007.40
# 28  2010-02-14 -1.00  -7.20  3.30  0.00 432.00    NaN 15.80  None 1,009.10
# 29  2010-02-15 -3.70 -12.80  2.80  1.50 381.00    NaN  4.70  None      NaN
# 30  2010-02-01 -4.50 -14.40  3.30  0.00  51.00    NaN  6.10  None 1,026.40
# 31  2010-02-02 -1.60  -9.40  4.40  7.10  25.00    NaN  3.20  None      NaN
# 32  2010-02-03  1.20  -2.80  4.40  0.50 102.00    NaN  8.30  None 1,020.20
# 33  2010-02-04  1.30  -2.80  4.40  0.00  51.00    NaN  7.60  None 1,028.70
# 34  2010-02-05  0.10  -1.10  1.70 37.30  25.00    NaN  9.70  None      NaN
# 35  2010-02-06 -2.90 -12.20  0.00 50.30 457.00    NaN 16.90  None      NaN
# 36  2010-02-07 -6.10 -13.90 -0.60  0.00 533.00    NaN 12.60  None 1,016.50
# 37  2010-02-08 -5.00 -10.60  0.00  0.00 508.00    NaN 11.90  None 1,021.00
# 38  2010-02-09 -4.60 -12.20  1.70  7.60 483.00    NaN  3.20  None      NaN
# 39  2010-02-10 -3.60  -6.70 -1.10 10.70 660.00 321.00 31.00  None      NaN
# 40  2010-02-11  0.10  -2.20  3.30  0.00 635.00 306.00 25.60  None 1,009.20
# 41  2010-02-12 -1.00  -5.00  2.80  0.00 508.00    NaN 13.00  None 1,013.30
# 42  2010-02-13 -1.80  -3.30  0.00  0.00 457.00 315.00 20.50  None 1,007.40
# 43  2010-02-14 -1.00  -7.20  3.30  0.00 432.00    NaN 15.80  None 1,009.10
# 44  2010-02-15 -3.70 -12.80  2.80  1.50 381.00    NaN  4.70  None      NaN
# 45  2010-02-01 -1.80  -6.10  2.20  0.00   0.00 270.00 16.20  None 1,025.30
# 46  2010-02-02 -0.60  -5.60  2.20  0.00   0.00    NaN  6.10  None      NaN
# 47  2010-02-03  1.30  -0.60  4.40  0.50  25.00    NaN 10.80  None      NaN
# 48  2010-02-04  1.30  -1.10  4.40  0.00   0.00 295.00 14.40  None 1,027.50
# 49  2010-02-05  0.50  -1.70  3.30 14.00   0.00    NaN  7.60  None 1,023.10
# 50  2010-02-06 -3.80  -8.30 -1.70 47.00 432.00  23.00 28.40  None 1,006.30
# 51  2010-02-07 -5.00 -10.00  0.00  0.00 508.00 314.00 16.60  None 1,013.80
# 52  2010-02-08 -3.80 -10.60  1.70  0.00 356.00 273.00 18.40  None 1,017.60
# 53  2010-02-09 -1.70  -7.20  2.80 14.00 279.00    NaN  7.90  None      NaN
# 54  2010-02-10 -0.70  -2.20  0.60 27.90 432.00   4.00 28.40  None      NaN
# 55  2010-02-11  0.20  -2.80  3.30  0.00 457.00 304.00 26.60  None 1,004.30
# 56  2010-02-12 -1.50  -5.60  1.70  0.00 356.00 301.00 15.50  None 1,011.70
# 57  2010-02-13 -2.50  -4.40 -0.60  0.00 305.00 311.00 18.00  None 1,004.80
# 58  2010-02-14 -1.20  -5.00  2.80  0.00 305.00 265.00 23.00  None 1,005.80
# 59  2010-02-15 -1.30  -6.10  2.80  2.30 254.00    NaN 11.90  None      NaN
#
#     tsun station_id  faa
# 0   None      74486  JFK
# 1   None      74486  JFK
# 2   None      74486  JFK
# 3   None      74486  JFK
# 4   None      74486  JFK
# 5   None      74486  JFK
# 6   None      74486  JFK
# 7   None      74486  JFK
# 8   None      74486  JFK
# 9   None      74486  JFK
# 10  None      74486  JFK
# 11  None      74486  JFK
# 12  None      74486  JFK
# 13  None      74486  JFK
# 14  None      74486  JFK
# 15  None      72403  IAD
# 16  None      72403  IAD
# 17  None      72403  IAD
# 18  None      72403  IAD
# 19  None      72403  IAD
# 20  None      72403  IAD
# 21  None      72403  IAD
# 22  None      72403  IAD
# 23  None      72403  IAD
# 24  None      72403  IAD
# 25  None      72403  IAD
# 26  None      72403  IAD
# 27  None      72403  IAD
# 28  None      72403  IAD
# 29  None      72403  IAD
# 30  None      72403  IAD
# 31  None      72403  IAD
# 32  None      72403  IAD
# 33  None      72403  IAD
# 34  None      72403  IAD
# 35  None      72403  IAD
# 36  None      72403  IAD
# 37  None      72403  IAD
# 38  None      72403  IAD
# 39  None      72403  IAD
# 40  None      72403  IAD
# 41  None      72403  IAD
# 42  None      72403  IAD
# 43  None      72403  IAD
# 44  None      72403  IAD
# 45  None      72408  PHL
# 46  None      72408  PHL
# 47  None      72408  PHL
# 48  None      72408  PHL
# 49  None      72408  PHL
# 50  None      72408  PHL
# 51  None      72408  PHL
# 52  None      72408  PHL
# 53  None      72408  PHL
# 54  None      72408  PHL
# 55  None      72408  PHL
# 56  None      72408  PHL
# 57  None      72408  PHL
# 58  None      72408  PHL
# 59  None      72408  PHL

# %%
#keeping only those columns, which are intersting for us (as defined in hypothesis)
weather_short_sf = weather_stacked_sf[['date', 'tavg', 'tmin', 'tmax', 'snow', 'wspd', 'faa']].copy()

# %%
weather_short_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    60 non-null     object
#  1   tavg    60 non-null     float64
#  2   tmin    60 non-null     float64
#  3   tmax    60 non-null     float64
#  4   snow    60 non-null     float64
#  5   wspd    60 non-null     float64
#  6   faa     60 non-null     object
# dtypes: float64(5), object(2)
# memory usage: 3.4+ KB

# %%
weather_short_sf['date']= pd.to_datetime(weather_short_sf['date'])

# %%
weather_short_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    60 non-null     datetime64[ns]
#  1   tavg    60 non-null     float64
#  2   tmin    60 non-null     float64
#  3   tmax    60 non-null     float64
#  4   snow    60 non-null     float64
#  5   wspd    60 non-null     float64
#  6   faa     60 non-null     object
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 3.4+ KB

# %%
weather_short_sf.describe()
# Out:
#        tavg   tmin  tmax   snow  wspd
# count 60.00  60.00 60.00  60.00 60.00
# mean  -1.63  -6.06  2.13 257.78 16.26
# std    2.08   4.14  1.75 223.20  8.69
# min   -6.10 -14.40 -1.70   0.00  3.20
# 25%   -3.60  -9.40  0.60  25.00  9.35
# 50%   -1.20  -5.00  2.80 254.00 15.65
# 75%    0.10  -2.80  3.30 457.00 22.48
# max    1.30  -0.60  4.40 660.00 33.10

# %%
weather_short_sf.isna().sum()
# Out:
# date    0
# tavg    0
# tmin    0
# tmax    0
# snow    0
# wspd    0
# faa     0
# dtype: int64

# %%
weather_short_sf.duplicated().value_counts()

# %%
#duplicates were checked and then excluded from the dataframe
weather_short_sf.drop_duplicates(inplace=True)

# %%
weather_short_sf.reset_index(drop=True, inplace=True)

# %%
weather_short_sf.rename(columns={'tavg':'averg_temp', 'tmin': 'min_temp', 'tmax': 'max_temp', 'wspd': 'windspeed'}, inplace=True)

weather_short_sf.head()
# Out:
#         date  averg_temp  min_temp  max_temp  snow  windspeed  faa
# 0 2010-02-01       -0.90     -3.90      2.80  0.00      22.30  JFK
# 1 2010-02-02       -1.00     -3.90      0.60  0.00      10.10  JFK
# 2 2010-02-03        0.30     -2.20      4.40 25.00      15.80  JFK
# 3 2010-02-04        0.80     -1.70      3.30  0.00      22.30  JFK
# 4 2010-02-05        0.60     -1.70      2.80  0.00      11.50  JFK

# %%
weather_short_sf
# Out:
#          date  averg_temp  min_temp  max_temp   snow  windspeed  faa
# 0  2010-02-01       -0.90     -3.90      2.80   0.00      22.30  JFK
# 1  2010-02-02       -1.00     -3.90      0.60   0.00      10.10  JFK
# 2  2010-02-03        0.30     -2.20      4.40  25.00      15.80  JFK
# 3  2010-02-04        0.80     -1.70      3.30   0.00      22.30  JFK
# 4  2010-02-05        0.60     -1.70      2.80   0.00      11.50  JFK
# 5  2010-02-06       -3.10     -6.10      0.60   0.00      33.10  JFK
# 6  2010-02-07       -4.20     -8.90      1.70  25.00      28.10  JFK
# 7  2010-02-08       -1.20     -5.00      3.90   0.00      27.70  JFK
# 8  2010-02-09        0.80     -2.20      4.40   0.00      15.10  JFK
# 9  2010-02-10       -0.20     -1.10      0.60  51.00      31.30  JFK
# 10 2010-02-11        0.20     -2.20      2.80 254.00      32.00  JFK
# 11 2010-02-12       -0.90     -3.90      2.20 229.00      22.00  JFK
# 12 2010-02-13       -2.30     -4.40      0.00 203.00      25.20  JFK
# 13 2010-02-14        0.10     -2.80      3.90 203.00      28.40  JFK
# 14 2010-02-15       -0.10     -2.80      2.80 152.00      20.90  JFK
# 15 2010-02-01       -4.50    -14.40      3.30  51.00       6.10  IAD
# 16 2010-02-02       -1.60     -9.40      4.40  25.00       3.20  IAD
# 17 2010-02-03        1.20     -2.80      4.40 102.00       8.30  IAD
# 18 2010-02-04        1.30     -2.80      4.40  51.00       7.60  IAD
# 19 2010-02-05        0.10     -1.10      1.70  25.00       9.70  IAD
# 20 2010-02-06       -2.90    -12.20      0.00 457.00      16.90  IAD
# 21 2010-02-07       -6.10    -13.90     -0.60 533.00      12.60  IAD
# 22 2010-02-08       -5.00    -10.60      0.00 508.00      11.90  IAD
# 23 2010-02-09       -4.60    -12.20      1.70 483.00       3.20  IAD
# 24 2010-02-10       -3.60     -6.70     -1.10 660.00      31.00  IAD
# 25 2010-02-11        0.10     -2.20      3.30 635.00      25.60  IAD
# 26 2010-02-12       -1.00     -5.00      2.80 508.00      13.00  IAD
# 27 2010-02-13       -1.80     -3.30      0.00 457.00      20.50  IAD
# 28 2010-02-14       -1.00     -7.20      3.30 432.00      15.80  IAD
# 29 2010-02-15       -3.70    -12.80      2.80 381.00       4.70  IAD
# 30 2010-02-01       -1.80     -6.10      2.20   0.00      16.20  PHL
# 31 2010-02-02       -0.60     -5.60      2.20   0.00       6.10  PHL
# 32 2010-02-03        1.30     -0.60      4.40  25.00      10.80  PHL
# 33 2010-02-04        1.30     -1.10      4.40   0.00      14.40  PHL
# 34 2010-02-05        0.50     -1.70      3.30   0.00       7.60  PHL
# 35 2010-02-06       -3.80     -8.30     -1.70 432.00      28.40  PHL
# 36 2010-02-07       -5.00    -10.00      0.00 508.00      16.60  PHL
# 37 2010-02-08       -3.80    -10.60      1.70 356.00      18.40  PHL
# 38 2010-02-09       -1.70     -7.20      2.80 279.00       7.90  PHL
# 39 2010-02-10       -0.70     -2.20      0.60 432.00      28.40  PHL
# 40 2010-02-11        0.20     -2.80      3.30 457.00      26.60  PHL
# 41 2010-02-12       -1.50     -5.60      1.70 356.00      15.50  PHL
# 42 2010-02-13       -2.50     -4.40     -0.60 305.00      18.00  PHL
# 43 2010-02-14       -1.20     -5.00      2.80 305.00      23.00  PHL
# 44 2010-02-15       -1.30     -6.10      2.80 254.00      11.90  PHL

# %%
weather_short_sf[['faa']].value_counts()
# Out:
# faa
# IAD    15
# JFK    15
# PHL    15
# dtype: int64

# %%
#SQL-quary to retrieve flights_group_x from DBEAVER (contains flights and airport data)

schema = 'hh_analytics_24_1'

sql_query = f'SELECT * FROM {schema}.flights_group_x'
flights_x_sf = get_dataframe(sql_query)
flights_x_sf.head()
# Out:
#   flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0  2010-02-02    727.00             730      -3.00    835.00             855
# 1  2010-02-02  1,536.00            1540      -4.00  1,646.00            1710
# 2  2010-02-02  1,239.00            1130      69.00  1,338.00            1255
# 3  2010-02-02  1,355.00            1355       0.00  1,514.00            1550
# 4  2010-02-02  1,026.00            1030      -4.00  1,145.00            1225
#
#    arr_delay airline tail_number  flight_number  ... air_time  \
# 0     -20.00      WN      N798SW             61  ...    43.00
# 1     -24.00      WN      N210WN             65  ...    40.00
# 2      43.00      WN      N207WN           2064  ...    42.00
# 3     -36.00      WN      N456WN            232  ...   111.00
# 4     -40.00      WN      N227WN           1510  ...   116.00
#
#   actual_elapsed_time  distance  cancelled  diverted   lat    lon      city  \
# 0               68.00    185.00          0         0 40.78 -73.87  New York
# 1               70.00    185.00          0         0 40.78 -73.87  New York
# 2               59.00    185.00          0         0 40.78 -73.87  New York
# 3              139.00    725.00          0         0 40.78 -73.87  New York
# 4              139.00    725.00          0         0 40.78 -73.87  New York
#
#    tz_origin tz_dest
# 0      -5.00   -5.00
# 1      -5.00   -5.00
# 2      -5.00   -5.00
# 3      -5.00   -6.00
# 4      -5.00   -6.00
#
# [5 rows x 22 columns]

# %%
flights_x_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50136 entries, 0 to 50135
# Data columns (total 22 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   flight_date          50136 non-null  datetime64[ns]
#  1   dep_time             43958 non-null  float64
#  2   sched_dep_time       50136 non-null  int64
#  3   dep_delay            43958 non-null  float64
#  4   arr_time             43864 non-null  float64
#  5   sched_arr_time       50136 non-null  int64
#  6   arr_delay            43748 non-null  float64
#  7   airline              50136 non-null  object
#  8   tail_number          46457 non-null  object
#  9   flight_number        50136 non-null  int64
#  10  origin               50136 non-null  object
#  11  dest                 50136 non-null  object
#  12  air_time             43748 non-null  float64
#  13  actual_elapsed_time  43748 non-null  float64
#  14  distance             50136 non-null  float64
#  15  cancelled            50136 non-null  int64
#  16  diverted             50136 non-null  int64
#  17  lat                  50136 non-null  float64
#  18  lon                  50136 non-null  float64
#  19  city                 50136 non-null  object
#  20  tz_origin            50136 non-null  float64
#  21  tz_dest              50136 non-null  float64
# dtypes: datetime64[ns](1), float64(11), int64(5), object(5)
# memory usage: 8.4+ MB

# %%
flights_x_sf.columns

# %%
flights_x_sf.origin.nunique()

# %%
type(flights_x_sf)
# Out:
# pandas.core.frame.DataFrame

# %%
#keeping only relevant columns

flights_short_sf = flights_x_sf[['flight_date', 'dep_time', 'flight_number', 'origin', 'cancelled', 'diverted', 'lat', 'lon', 'city']].copy()

# %%
flights_short_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50136 entries, 0 to 50135
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    50136 non-null  datetime64[ns]
#  1   dep_time       43958 non-null  float64
#  2   flight_number  50136 non-null  int64
#  3   origin         50136 non-null  object
#  4   cancelled      50136 non-null  int64
#  5   diverted       50136 non-null  int64
#  6   lat            50136 non-null  float64
#  7   lon            50136 non-null  float64
#  8   city           50136 non-null  object
# dtypes: datetime64[ns](1), float64(3), int64(3), object(2)
# memory usage: 3.4+ MB

# %%
flights_short_sf.isna().sum()

# %%
flights_short_sf.isnull().sum()

# %%
flights_short_sf

# %%
flights_short_sf.tail(50)

# %%
flights_short_sf.duplicated().value_counts()
# Out:
# False    50093
# True        43
# dtype: int64

# %%
#Some flights are recorded twice: once as not canclled and once as cancelled.When doing our analysis we need to filter for those flights where cancelled==1

duplicated_rows = flights_short_sf[flights_short_sf.duplicated()]
print(duplicated_rows)
# Out:
#       flight_date  dep_time  flight_number origin  cancelled  diverted   lat  \
# 8881   2010-02-10       NaN            201    JFK          1         0 40.64
# 9003   2010-02-10       NaN             59    JFK          1         0 40.64
# 13038  2010-02-10       NaN           2549    EWR          1         0 40.69
# 14379  2010-02-10       NaN            177    JFK          1         0 40.64
# 15673  2010-02-10       NaN              1    JFK          1         0 40.64
# 15703  2010-02-10       NaN            181    JFK          1         0 40.64
# 15704  2010-02-10       NaN            185    JFK          1         0 40.64
# 15722  2010-02-10       NaN             21    JFK          1         0 40.64
# 15732  2010-02-10       NaN            371    LGA          1         0 40.78
# 20562  2010-02-26       NaN            185    JFK          1         0 40.64
# 26255  2010-02-10       NaN            525    EWR          1         0 40.69
# 26300  2010-02-10       NaN           1107    EWR          1         0 40.69
# 30413  2010-02-10       NaN            133    JFK          1         0 40.64
# 30423  2010-02-10       NaN            209    JFK          1         0 40.64
# 30434  2010-02-10       NaN            701    JFK          1         0 40.64
# 30442  2010-02-10       NaN            715    JFK          1         0 40.64
# 30457  2010-02-10       NaN            735    JFK          1         0 40.64
# 30472  2010-02-10       NaN           1185    EWR          1         0 40.69
# 30544  2010-02-10       NaN           1800    FLL          1         0 26.07
# 30589  2010-02-11       NaN             33    JFK          1         0 40.64
# 33602  2010-02-26       NaN             33    JFK          1         0 40.64
# 33603  2010-02-26       NaN             57    JFK          1         0 40.64
# 33772  2010-02-26       NaN           1800    FLL          1         0 26.07
# 34368  2010-02-10       NaN           2190    LGA          1         0 40.78
# 35059  2010-02-26       NaN           2397    JFK          1         0 40.64
# 36897  2010-02-10       NaN            369    LGA          1         0 40.78
# 36930  2010-02-11       NaN            363    LGA          1         0 40.78
# 37478  2010-02-26       NaN            363    LGA          1         0 40.78
# 45104  2010-02-10       NaN             29    JFK          1         0 40.64
# 45453  2010-02-10       NaN             15    JFK          1         0 40.64
# 45469  2010-02-26       NaN             15    JFK          1         0 40.64
# 45505  2010-02-10       NaN             22    LAX          1         0 33.94
# 45805  2010-02-10       NaN             84    LAX          1         0 33.94
# 45919  2010-02-25       NaN             91    EWR          1         0 40.69
# 45920  2010-02-26       NaN             91    EWR          1         0 40.69
# 46025  2010-02-10       NaN            311    EWR          1         0 40.69
# 46054  2010-02-10       NaN            327    LGA          1         0 40.78
# 46094  2010-02-10       NaN            361    LGA          1         0 40.78
# 46110  2010-02-26       NaN            361    LGA          1         0 40.78
# 46280  2010-02-25       NaN            525    EWR          1         0 40.69
# 48249  2010-02-10       NaN            173    JFK          1         0 40.64
# 49828  2010-02-25       NaN           2179    LGA          1         0 40.78
# 49927  2010-02-26       NaN           1509    LGA          1         0 40.78
#
#           lon             city
# 8881   -73.78         New York
# 9003   -73.78         New York
# 13038  -74.17           Newark
# 14379  -73.78         New York
# 15673  -73.78         New York
# 15703  -73.78         New York
# 15704  -73.78         New York
# 15722  -73.78         New York
# 15732  -73.87         New York
# 20562  -73.78         New York
# 26255  -74.17           Newark
# 26300  -74.17           Newark
# 30413  -73.78         New York
# 30423  -73.78         New York
# 30434  -73.78         New York
# 30442  -73.78         New York
# 30457  -73.78         New York
# 30472  -74.17           Newark
# 30544  -80.15  Fort Lauderdale
# 30589  -73.78         New York
# 33602  -73.78         New York
# 33603  -73.78         New York
# 33772  -80.15  Fort Lauderdale
# 34368  -73.87         New York
# 35059  -73.78         New York
# 36897  -73.87         New York
# 36930  -73.87         New York
# 37478  -73.87         New York
# 45104  -73.78         New York
# 45453  -73.78         New York
# 45469  -73.78         New York
# 45505 -118.41      Los Angeles
# 45805 -118.41      Los Angeles
# 45919  -74.17           Newark
# 45920  -74.17           Newark
# 46025  -74.17           Newark
# 46054  -73.87         New York
# 46094  -73.87         New York
# 46110  -73.87         New York
# 46280  -74.17           Newark
# 48249  -73.78         New York
# 49828  -73.87         New York
# 49927  -73.87         New York

# %%
flights_short_sf[flights_short_sf['flight_number'] == 201]

# %%
#flights_short.reset_index(drop=True, inplace=True)

# %%
flights_short_sf

# %%
#Inner merge was done to analyze only those dates for which we have weather date available

merged_df = flights_short_sf.merge(weather_short_sf, how='inner', left_on='origin', right_on='faa')

# Display the merged DataFrame
merged_df
# Out:
#        flight_date  dep_time  flight_number origin  cancelled  diverted   lat  \
# 0       2010-02-05       NaN           5728    IAD          1         0 38.94
# 1       2010-02-05       NaN           5728    IAD          1         0 38.94
# 2       2010-02-05       NaN           5728    IAD          1         0 38.94
# 3       2010-02-05       NaN           5728    IAD          1         0 38.94
# 4       2010-02-05       NaN           5728    IAD          1         0 38.94
# ...            ...       ...            ...    ...        ...       ...   ...
# 140530  2010-02-28  2,245.00           1290    PHL          0         0 39.87
# 140531  2010-02-28  2,245.00           1290    PHL          0         0 39.87
# 140532  2010-02-28  2,245.00           1290    PHL          0         0 39.87
# 140533  2010-02-28  2,245.00           1290    PHL          0         0 39.87
# 140534  2010-02-28  2,245.00           1290    PHL          0         0 39.87
#
#           lon          city       date  averg_temp  min_temp  max_temp   snow  \
# 0      -77.46    Washington 2010-02-01       -4.50    -14.40      3.30  51.00
# 1      -77.46    Washington 2010-02-02       -1.60     -9.40      4.40  25.00
# 2      -77.46    Washington 2010-02-03        1.20     -2.80      4.40 102.00
# 3      -77.46    Washington 2010-02-04        1.30     -2.80      4.40  51.00
# 4      -77.46    Washington 2010-02-05        0.10     -1.10      1.70  25.00
# ...       ...           ...        ...         ...       ...       ...    ...
# 140530 -75.24  Philadelphia 2010-02-11        0.20     -2.80      3.30 457.00
# 140531 -75.24  Philadelphia 2010-02-12       -1.50     -5.60      1.70 356.00
# 140532 -75.24  Philadelphia 2010-02-13       -2.50     -4.40     -0.60 305.00
# 140533 -75.24  Philadelphia 2010-02-14       -1.20     -5.00      2.80 305.00
# 140534 -75.24  Philadelphia 2010-02-15       -1.30     -6.10      2.80 254.00
#
#         windspeed  faa
# 0            6.10  IAD
# 1            3.20  IAD
# 2            8.30  IAD
# 3            7.60  IAD
# 4            9.70  IAD
# ...           ...  ...
# 140530      26.60  PHL
# 140531      15.50  PHL
# 140532      18.00  PHL
# 140533      23.00  PHL
# 140534      11.90  PHL
#
# [140535 rows x 16 columns]

# %%
# the flight_date and date columns do not match in merged_df
merged_df_sf = flights_short_sf.merge(weather_short_sf, 
                                   how='inner', 
                                   left_on=['origin', 'flight_date'], 
                                   right_on=['faa', 'date'])

# %%
merged_df_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4924 entries, 0 to 4923
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    4924 non-null   datetime64[ns]
#  1   dep_time       4334 non-null   float64
#  2   flight_number  4924 non-null   int64
#  3   origin         4924 non-null   object
#  4   cancelled      4924 non-null   int64
#  5   diverted       4924 non-null   int64
#  6   lat            4924 non-null   float64
#  7   lon            4924 non-null   float64
#  8   city           4924 non-null   object
#  9   date           4924 non-null   datetime64[ns]
#  10  averg_temp     4924 non-null   float64
#  11  min_temp       4924 non-null   float64
#  12  max_temp       4924 non-null   float64
#  13  snow           4924 non-null   float64
#  14  windspeed      4924 non-null   float64
#  15  faa            4924 non-null   object
# dtypes: datetime64[ns](2), float64(8), int64(3), object(3)
# memory usage: 654.0+ KB

# %%
merged_df_sf.drop(columns=['faa'], inplace=True)

# %%
merged_df_sf.drop(columns=['date'], inplace=True)

# %%
weather_flights_x_sf = merged_df_sf

# %%
weather_flights_x_sf
# Out:
#      flight_date  dep_time  flight_number origin  cancelled  diverted   lat  \
# 0     2010-02-05       NaN           5728    IAD          1         0 38.94
# 1     2010-02-05       NaN           5729    IAD          1         0 38.94
# 2     2010-02-05       NaN           3010    IAD          1         0 38.94
# 3     2010-02-05    816.00           5726    IAD          0         0 38.94
# 4     2010-02-05  1,238.00           5727    IAD          0         0 38.94
# ...          ...       ...            ...    ...        ...       ...   ...
# 4919  2010-02-13  2,023.00           1156    PHL          0         0 39.87
# 4920  2010-02-14  1,415.00           6681    PHL          0         0 39.87
# 4921  2010-02-14  2,243.00           1290    PHL          0         0 39.87
# 4922  2010-02-15  1,427.00           6681    PHL          0         0 39.87
# 4923  2010-02-15  2,246.00           1290    PHL          0         0 39.87
#
#         lon          city  averg_temp  min_temp  max_temp   snow  windspeed
# 0    -77.46    Washington        0.10     -1.10      1.70  25.00       9.70
# 1    -77.46    Washington        0.10     -1.10      1.70  25.00       9.70
# 2    -77.46    Washington        0.10     -1.10      1.70  25.00       9.70
# 3    -77.46    Washington        0.10     -1.10      1.70  25.00       9.70
# 4    -77.46    Washington        0.10     -1.10      1.70  25.00       9.70
# ...     ...           ...         ...       ...       ...    ...        ...
# 4919 -75.24  Philadelphia       -2.50     -4.40     -0.60 305.00      18.00
# 4920 -75.24  Philadelphia       -1.20     -5.00      2.80 305.00      23.00
# 4921 -75.24  Philadelphia       -1.20     -5.00      2.80 305.00      23.00
# 4922 -75.24  Philadelphia       -1.30     -6.10      2.80 254.00      11.90
# 4923 -75.24  Philadelphia       -1.30     -6.10      2.80 254.00      11.90
#
# [4924 rows x 14 columns]

# %%
#pushing merged dataframe to postgres

from sql_functions import get_engine
engine = get_engine()

# %%
schema = 'hh_analytics_24_1' # your course schema name, example 'hh_analytics_22_1
table_name = 'weather_flights_x_sf' # Example: 'carriers_pw' for Philipp Wendt

# %%
import psycopg2

# %%
# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        weather_flights_x_sf.to_sql(name=table_name, # Name of SQL table variable
                        con=engine, # Engine or connection
                        schema=schema, # your class schema variable
                        if_exists='replace', # Drop the table before inserting new values 
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
else:
    print('No engine')
# Out:
# The weather_flights_x_sf table was imported successfully.

# %%
weather_flights_x_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4924 entries, 0 to 4923
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    4924 non-null   datetime64[ns]
#  1   dep_time       4334 non-null   float64
#  2   flight_number  4924 non-null   int64
#  3   origin         4924 non-null   object
#  4   cancelled      4924 non-null   int64
#  5   diverted       4924 non-null   int64
#  6   lat            4924 non-null   float64
#  7   lon            4924 non-null   float64
#  8   city           4924 non-null   object
#  9   averg_temp     4924 non-null   float64
#  10  min_temp       4924 non-null   float64
#  11  max_temp       4924 non-null   float64
#  12  snow           4924 non-null   float64
#  13  windspeed      4924 non-null   float64
# dtypes: datetime64[ns](1), float64(8), int64(3), object(2)
# memory usage: 577.0+ KB

# %%
# Convert 'flight_date' column to datetime format
weather_flights_x_sf['flight_date'] = pd.to_datetime(weather_flights_x_sf['flight_date'])

# Format the flight dates to 'yyyy:mm:dd'
weather_flights_x_sf['flight_date'] = weather_flights_x_sf['flight_date'].dt.strftime('%Y:%m:%d')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:536, in pandas._libs.tslib.array_to_datetime()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 2010:02:05
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:547, in pandas._libs.tslib.array_to_datetime()
#
# TypeError: invalid string coercion to datetime
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:649, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648 try:
# --> 649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:1235, in parser._build_naive(self, res, default)
#    1233         repl['day'] = monthrange(cyear, cmonth)[1]
# -> 1235 naive = default.replace(**repl)
#    1237 if res.weekday is not None and not res.day:
#
# ValueError: hour must be in 0..23
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# Cell In[138], line 2
#       1 # Convert 'flight_date' column to datetime format
# ----> 2 weather_flights_x_sf['flight_date'] = pd.to_datetime(weather_flights_x_sf['flight_date'])
#       4 # Format the flight dates to 'yyyy:mm:dd'
#       5 weather_flights_x_sf['flight_date'] = weather_flights_x_sf['flight_date'].dt.strftime('%Y:%m:%d')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:402, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     400 assert format is None or infer_datetime_format
#     401 utc = tz == "utc"
# --> 402 result, tz_parsed = objects_to_datetime64ns(
#     403     arg,
#     404     dayfirst=dayfirst,
#     405     yearfirst=yearfirst,
#     406     utc=utc,
#     407     errors=errors,
#     408     require_iso8601=require_iso8601,
#     409     allow_object=True,
#     410 )
#     412 if tz_parsed is not None:
#     413     # We can take a shortcut since the datetime64 numpy array
#     414     # is in UTC
#     415     dta = DatetimeArray(result, dtype=tz_to_dtype(tz_parsed))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2217, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2215         return values.view("i8"), tz_parsed
#    2216     except (ValueError, TypeError):
# -> 2217         raise err
#    2219 if tz_parsed is not None:
#    2220     # We can take a shortcut since the datetime64 numpy array
#    2221     #  is in UTC
#    2222     # Return i8 values to denote unix timestamps
#    2223     return result.view("i8"), tz_parsed
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/arrays/datetimes.py:2199, in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object, allow_mixed)
#    2197 order: Literal["F", "C"] = "F" if flags.f_contiguous else "C"
#    2198 try:
# -> 2199     result, tz_parsed = tslib.array_to_datetime(
#    2200         data.ravel("K"),
#    2201         errors=errors,
#    2202         utc=utc,
#    2203         dayfirst=dayfirst,
#    2204         yearfirst=yearfirst,
#    2205         require_iso8601=require_iso8601,
#    2206         allow_mixed=allow_mixed,
#    2207     )
#    2208     result = result.reshape(data.shape, order=order)
#    2209 except ValueError as err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:381, in pandas._libs.tslib.array_to_datetime()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:613, in pandas._libs.tslib.array_to_datetime()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:751, in pandas._libs.tslib._array_to_datetime_object()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslib.pyx:742, in pandas._libs.tslib._array_to_datetime_object()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslibs/parsing.pyx:281, in pandas._libs.tslibs.parsing.parse_datetime_string()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:1368, in parse(timestr, parserinfo, **kwargs)
#    1366     return parser(parserinfo).parse(timestr, **kwargs)
#    1367 else:
# -> 1368     return DEFAULTPARSER.parse(timestr, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/dateutil/parser/_parser.py:651, in parser.parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     649     ret = self._build_naive(res, default)
#     650 except ValueError as e:
# --> 651     six.raise_from(ParserError(str(e) + ": %s", timestr), e)
#     653 if not ignoretz:
#     654     ret = self._build_tzaware(ret, res, tzinfos)
#
# File <string>:3, in raise_from(value, from_value)
#
# ParserError: hour must be in 0..23: 2010:02:05

# %%
weather_flights_x_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4924 entries, 0 to 4923
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    4924 non-null   object
#  1   dep_time       4334 non-null   float64
#  2   flight_number  4924 non-null   int64
#  3   origin         4924 non-null   object
#  4   cancelled      4924 non-null   category
#  5   diverted       4924 non-null   int64
#  6   lat            4924 non-null   float64
#  7   lon            4924 non-null   float64
#  8   city           4924 non-null   object
#  9   averg_temp     4924 non-null   float64
#  10  min_temp       4924 non-null   float64
#  11  max_temp       4924 non-null   float64
#  12  snow           4924 non-null   float64
#  13  windspeed      4924 non-null   float64
# dtypes: category(1), float64(8), int64(2), object(3)
# memory usage: 543.5+ KB

# %%
#2. Descriptive statistics in SQL (DBEAVER)

# %%
from sql_functions import get_dataframe
from sql_functions import get_engine

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as  sns

# %%
schema = 'hh_analytics_24_1'

sql_query = f'SELECT * FROM {schema}.weather_flights_x_sf'
flights = get_dataframe(sql_query)

flights.head(20)
# Out:
#    flight_date  dep_time  flight_number origin  cancelled  diverted   lat  \
# 0   2010-02-05       NaN           5728    IAD          1         0 38.94
# 1   2010-02-05       NaN           5729    IAD          1         0 38.94
# 2   2010-02-05       NaN           3010    IAD          1         0 38.94
# 3   2010-02-05    816.00           5726    IAD          0         0 38.94
# 4   2010-02-05  1,238.00           5727    IAD          0         0 38.94
# 5   2010-02-05       NaN           7300    IAD          1         0 38.94
# 6   2010-02-05       NaN           7185    IAD          1         0 38.94
# 7   2010-02-05    822.00           7205    IAD          0         0 38.94
# 8   2010-02-05       NaN           7206    IAD          1         0 38.94
# 9   2010-02-05       NaN           7256    IAD          1         0 38.94
# 10  2010-02-05    709.00           7209    IAD          0         0 38.94
# 11  2010-02-05       NaN           7236    IAD          1         0 38.94
# 12  2010-02-05  1,055.00           1304    IAD          0         0 38.94
# 13  2010-02-05  1,513.00           1306    IAD          0         0 38.94
# 14  2010-02-05       NaN           1310    IAD          1         0 38.94
# 15  2010-02-05  1,420.00           6581    IAD          0         0 38.94
# 16  2010-02-06       NaN           5678    IAD          1         0 38.94
# 17  2010-02-06       NaN           5694    IAD          1         0 38.94
# 18  2010-02-06       NaN           5726    IAD          1         0 38.94
# 19  2010-02-06       NaN           3010    IAD          1         0 38.94
#
#       lon        city  averg_temp  min_temp  max_temp   snow  windspeed
# 0  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 1  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 2  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 3  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 4  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 5  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 6  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 7  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 8  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 9  -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 10 -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 11 -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 12 -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 13 -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 14 -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 15 -77.46  Washington        0.10     -1.10      1.70  25.00       9.70
# 16 -77.46  Washington       -2.90    -12.20      0.00 457.00      16.90
# 17 -77.46  Washington       -2.90    -12.20      0.00 457.00      16.90
# 18 -77.46  Washington       -2.90    -12.20      0.00 457.00      16.90
# 19 -77.46  Washington       -2.90    -12.20      0.00 457.00      16.90

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(2, 3, figsize=(20, 10))  # create subplots on 2 rows and 3 columns
plt.suptitle('Distribution of weather conditions', fontsize=20)
fig.tight_layout()  # tight_layout automatically adjusts subplot params so that the subplot(s) fits into the figure area
plt.subplots_adjust(hspace=0.5, wspace=0.2, top=0.9)  # adjusts the space between the single subplots

# Boxplot for snowfall
ax[0][0].boxplot(x=weather_flights_x_sf['snow'])
ax[0][0].set_xticklabels(labels=["Snowfall in mm"])
ax[0][0].set_ylim(0, 1000)
ax[0][0].set_title("Distribution of snowfall", fontsize=15)

# Boxplot for maximum temperature
ax[0][1].boxplot(x=weather_flights_x_sf['max_temp'])
ax[0][1].set_xticklabels(labels=["Maximum temperature in Celcius"])
ax[0][1].set_ylim(-10, 20)
ax[0][1].set_title("Distribution of maximum temperature", fontsize=15)

# Boxplot for minimum temperature
ax[0][2].boxplot(x=weather_flights_x_sf['min_temp'])
ax[0][2].set_xticklabels(labels=["Minimum temperature in Celcius"])
ax[0][2].set_ylim(-20, 10)
ax[0][2].set_title("Distribution of minimum temperature", fontsize=15)

# Boxplot for average temperature
ax[1][0].boxplot(x=weather_flights_x_sf['averg_temp'])
ax[1][0].set_xticklabels(labels=["Average temperature in Celcius"])
ax[1][0].set_ylim(-10, 10)
ax[1][0].set_title("Distribution of average temperature", fontsize=15)

# Boxplot for windspeed
ax[1][1].boxplot(x=weather_flights_x_sf['windspeed'])
ax[1][1].set_xticklabels(labels=["Windspeed in km/h"])
ax[1][1].set_ylim(0, 60)
ax[1][1].set_title("Distribution of windspeed", fontsize=15)

# Remove the last subplot
fig.delaxes(ax[1][2])

plt.show()

# %%
fig, ax = plt.subplots(2,3, figsize=(20,10)) # create subplots on 2 rows and 3 columns
plt.suptitle('Distribution of Weather conditions', fontsize=20)
fig.tight_layout() # tight_layout automatically adjusts subplot params so that the subplot(s) fits in to the figure area
plt.subplots_adjust(hspace = .5, wspace = .2, top = .9) # adjusts the space between the single subplots

ax[0][0].hist(x=weather_flights_x_sf['snow'], bins=10)  # creates histogram for number of views
ax[0][0].set_xlabel("Snow in mm", fontsize = 10) # sets the label y-axis
ax[0][0].set_xlim(0,1000) # limits the x-axis values from 0 to 1000000 
ax[0][0].set_title("Distribution of snowfall", fontsize = 15);  # sets title for subplot

ax[0][1].hist(x= weather_flights_x_sf['windspeed'], bins=10)
ax[0][1].set_xlabel("Windspeed in km/h", fontsize = 10)
ax[0][1].set_xlim(0,60)
ax[0][1].set_title("Distribution of windspeed count", fontsize = 15);

ax[0][2].hist(x=weather_flights_x_sf['min_temp'], bins=10)
ax[0][2].set_xlabel("Minimum temperature in C", fontsize = 10)
ax[0][2].set_xlim(-20, 10)
ax[0][2].set_title("Distribution of min temperature count", fontsize = 15);

ax[1][0].hist(x=weather_flights_x_sf['max_temp'], bins=10)
ax[1][0].set_xlabel("max_temp in C", fontsize = 10)
ax[1][0].set_xlim(-10, 20)
ax[1][0].set_title("Distribution of max temperature count", fontsize = 15);
                              
ax[1][1].hist(x=weather_flights_x_sf['averg_temp'], bins=10)
ax[1][1].set_xlabel("average temperature in C", fontsize = 10)
ax[1][1].set_xlim(-10,10)
ax[1][1].set_title("Distribution of average temperature count", fontsize = 15);

fig.delaxes(ax[1][2]);

# %%
#Addressing hypothesis 2: 
#There is a correlation between certain weather conditions (wind speed, snowfall as well as temperature) and the number of flight cancellations.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Sort the DataFrame by 'flight_date'
weather_flights_x_sf_sorted = weather_flights_x_sf.sort_values(by='flight_date')

fig, ax = plt.subplots(2, 3, figsize=(40, 30))  # create subplots on 2 rows and 3 columns
plt.suptitle('Weather conditions per day', fontsize=20)
fig.tight_layout()  # tight_layout automatically adjusts subplot params so that the subplot(s) fits into the figure area
plt.subplots_adjust(hspace=0.6, wspace=0.2, top=0.9)  # adjusts the space between the single subplots

# Barplot for snow per day
sns.barplot(x=weather_flights_x_sf_sorted["flight_date"], y=weather_flights_x_sf_sorted['snow'], hue=weather_flights_x_sf_sorted['origin'], ax=ax[0, 0])
ax[0, 0].tick_params(axis='x', labelrotation=90)  # sets the label y-axis
ax[0, 0].set(xlabel=None)  # sets the x-axis label
ax[0, 0].set_ylabel("Snowfall", fontsize=10)  # sets the y-axis label
ax[0, 0].set_title("Snowfall per day", fontsize=15)  # sets title for subplot

plt.show()

# Barplot for average temperature per day
sns.barplot(x=weather_flights_x_sf_sorted["flight_date"], y=weather_flights_x_sf_sorted['averg_temp'], hue=weather_flights_x_sf_sorted['origin'], ax=ax[0, 1])
ax[0, 1].tick_params(axis='x', labelrotation=90)  # sets the label y-axis
ax[0, 1].set(xlabel=None)  # sets the x-axis label
ax[0, 1].set_ylabel("Average temperature", fontsize=10)  # sets the y-axis label
ax[0, 1].set_title("Average temperature per day", fontsize=15)  # sets title for subplot

plt.show()

# Barplot for windspeed per day
sns.barplot(x=weather_flights_x_sf_sorted["flight_date"], y=weather_flights_x_sf_sorted['windspeed'], ax=ax[0, 2])
ax[0, 2].tick_params(axis='x', labelrotation=90)  # sets the label y-axis
ax[0, 2].set(xlabel=None)  # sets the x-axis label
ax[0, 2].set_ylabel("Windspeed", fontsize=10)  # sets the y-axis label
ax[0, 2].set_title("Windspeedper day", fontsize=15)  # sets title for subplot

plt.show()
#fig.delaxes(ax[1][2]);

# %%
import seaborn as sns

# Sort the DataFrame by 'flight_date'
weather_flights_x_sf_sorted = weather_flights_x_sf.sort_values(by='flight_date') 

fig, ax = plt.subplots(1, 3, figsize=(20, 6))  # create subplots on 1 row and 3 columns
plt.suptitle('Weather conditions per day by origin', fontsize=20)
fig.tight_layout()  # tight_layout automatically adjusts subplot params so that the subplot(s) fits into the figure area

# Barplot for snow per day by origin
f1 = sns.barplot(x=weather_flights_x_sf_sorted["flight_date"], y=weather_flights_x_sf_sorted['snow'], hue=weather_flights_x_sf_sorted['origin'], ax=ax[0])
f1.tick_params(axis='x', labelrotation=90)  # sets the label y-axis
f1.set(xlabel=None)  # sets the x-axis label
f1.set_ylabel("Snow in mm", fontsize=10)  # sets the y-axis label
f1.set_title("Snow per day", fontsize=15)  # sets title for subplot

# Barplot for windspeed per day by origin
f2 = sns.barplot(x=weather_flights_x_sf_sorted["flight_date"], y=weather_flights_x_sf_sorted['windspeed'], hue=weather_flights_x_sf_sorted['origin'], ax=ax[1])
f2.tick_params(axis='x', labelrotation=90)  # sets the label y-axis
f2.set(xlabel=None)  # sets the x-axis label
f2.set_ylabel("Windspeed in km/h", fontsize=10)  # sets the y-axis label
f2.set_title("Windspeed per day", fontsize=15)  # sets title for subplot

# Barplot for average temperature per day by origin
f3 = sns.barplot(x=weather_flights_x_sf_sorted["flight_date"], y=weather_flights_x_sf_sorted['averg_temp'], hue=weather_flights_x_sf_sorted['origin'], ax=ax[2])
f3.tick_params(axis='x', labelrotation=90)  # sets the label y-axis
f3.set(xlabel=None)  # sets the x-axis label
f3.set_ylabel("Average temperature in Celcius", fontsize=10)  # sets the y-axis label
f3.set_title("Average temperature per day", fontsize=15)  # sets title for subplot

plt.show()

# %%
#weather_flights_x_sf_sorted['cancelled'] = weather_flights_x_sf_sorted['cancelled'].astype(bool)

weather_flights_x_sf['cancelled'] = weather_flights_x_sf['cancelled'].astype('category')

# %%
sns.displot(weather_flights_x_sf_sorted, x="flight_date", hue="cancelled", multiple="stack")

# %%
weather_flights_x_sf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4924 entries, 0 to 4923
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   flight_date    4924 non-null   object
#  1   dep_time       4334 non-null   float64
#  2   flight_number  4924 non-null   int64
#  3   origin         4924 non-null   object
#  4   cancelled      4924 non-null   category
#  5   diverted       4924 non-null   int64
#  6   lat            4924 non-null   float64
#  7   lon            4924 non-null   float64
#  8   city           4924 non-null   object
#  9   averg_temp     4924 non-null   float64
#  10  min_temp       4924 non-null   float64
#  11  max_temp       4924 non-null   float64
#  12  snow           4924 non-null   float64
#  13  windspeed      4924 non-null   float64
# dtypes: category(1), float64(8), int64(2), object(3)
# memory usage: 543.5+ KB

# %%
weather_flights_x_sf['flight_date'] = pd.to_datetime(weather_flights_x_sf['flight_date'], format='%y:%m:%d')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:510, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     509 try:
# --> 510     values, tz = conversion.datetime_to_datetime64(arg)
#     511     dta = DatetimeArray(values, dtype=tz_to_dtype(tz))
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslibs/conversion.pyx:360, in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[142], line 1
# ----> 1 weather_flights_x_sf['flight_date'] = pd.to_datetime(weather_flights_x_sf['flight_date'], format='%y:%m:%d')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:1047, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1045             result = arg.tz_localize(tz)
#    1046 elif isinstance(arg, ABCSeries):
# -> 1047     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1048     if not cache_array.empty:
#    1049         result = arg.map(cache_array)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:197, in _maybe_cache(arg, format, cache, convert_listlike)
#     195 unique_dates = unique(arg)
#     196 if len(unique_dates) < len(arg):
# --> 197     cache_dates = convert_listlike(unique_dates, format)
#     198     cache_array = Series(cache_dates, index=unique_dates)
#     199     # GH#39882 and GH#35888 in case of None and NaT we get duplicates
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:394, in _convert_listlike_datetimes(arg, format, name, tz, unit, errors, infer_datetime_format, dayfirst, yearfirst, exact)
#     391         format = None
#     393 if format is not None:
# --> 394     res = _to_datetime_with_format(
#     395         arg, orig_arg, name, tz, format, exact, errors, infer_datetime_format
#     396     )
#     397     if res is not None:
#     398         return res
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:514, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     512     return DatetimeIndex._simple_new(dta, name=name)
#     513 except (ValueError, TypeError):
# --> 514     raise err
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:501, in _to_datetime_with_format(arg, orig_arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     498             return _box_as_indexlike(result, utc=utc, name=name)
#     500     # fallback
# --> 501     res = _array_strptime_with_fallback(
#     502         arg, name, tz, fmt, exact, errors, infer_datetime_format
#     503     )
#     504     return res
#     506 except ValueError as err:
#     507     # Fallback to try to convert datetime objects if timezone-aware
#     508     #  datetime objects are found without passing `utc=True`
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/tools/datetimes.py:437, in _array_strptime_with_fallback(arg, name, tz, fmt, exact, errors, infer_datetime_format)
#     434 utc = tz == "utc"
#     436 try:
# --> 437     result, timezones = array_strptime(arg, fmt, exact=exact, errors=errors)
#     438     if "%Z" in fmt or "%z" in fmt:
#     439         return _return_parsed_timezone_results(result, timezones, tz, name)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/tslibs/strptime.pyx:150, in pandas._libs.tslibs.strptime.array_strptime()
#
# ValueError: time data '2010:02:05' does not match format '%y:%m:%d' (match)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a bar plot
plt.figure(figsize=(10, 6))
sns.countplot(data=weather_flights_x_sf, x='flight_date', hue='cancelled')
plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
plt.xlabel('Flight Date')
plt.ylabel('Count')
plt.title('Counts of Cancelled Flights by Date')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[134], line 6
#       4 # Create a bar plot
#       5 plt.figure(figsize=(10, 6))
# ----> 6 sns.countplot(data=weather_flights_x_sf, x='flight_date', hue='cancelled')
#       7 plt.xticks(rotation=90)  # Rotate x-axis labels by 90 degrees
#       8 plt.xlabel('Flight Date')
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/seaborn/categorical.py:2955, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2952 if ax is None:
#    2953     ax = plt.gca()
# -> 2955 plotter.plot(ax, kwargs)
#    2956 return ax
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/seaborn/categorical.py:1587, in _BarPlotter.plot(self, ax, bar_kws)
#    1585 """Make the plot."""
#    1586 self.draw_bars(ax, bar_kws)
# -> 1587 self.annotate_axes(ax)
#    1588 if self.orient == "h":
#    1589     ax.invert_yaxis()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/seaborn/categorical.py:767, in _CategoricalPlotter.annotate_axes(self, ax)
#     764     ax.set_ylim(-.5, len(self.plot_data) - .5, auto=None)
#     766 if self.hue_names is not None:
# --> 767     ax.legend(loc="best", title=self.hue_title)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/matplotlib/axes/_axes.py:322, in Axes.legend(self, *args, **kwargs)
#     204 @_docstring.dedent_interpd
#     205 def legend(self, *args, **kwargs):
#     206     """
#     207     Place a legend on the Axes.
#     208
#    (...)
#     320     .. plot:: gallery/text_labels_and_annotations/legend.py
#     321     """
# --> 322     handles, labels, kwargs = mlegend._parse_legend_args([self], *args, **kwargs)
#     323     self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     324     self.legend_._remove_method = self._remove_legend
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/matplotlib/legend.py:1361, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1357     handles = [handle for handle, label
#    1358                in zip(_get_legend_handles(axs, handlers), labels)]
#    1360 elif len(args) == 0:  # 0 args: automatically detect labels and handles.
# -> 1361     handles, labels = _get_legend_handles_labels(axs, handlers)
#    1362     if not handles:
#    1363         log.warning(
#    1364             "No artists with labels found to put in legend.  Note that "
#    1365             "artists whose label start with an underscore are ignored "
#    1366             "when legend() is called with no argument.")
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/matplotlib/legend.py:1291, in _get_legend_handles_labels(axs, legend_handler_map)
#    1289 for handle in _get_legend_handles(axs, legend_handler_map):
#    1290     label = handle.get_label()
# -> 1291     if label and not label.startswith('_'):
#    1292         handles.append(handle)
#    1293         labels.append(label)
#
# AttributeError: 'int' object has no attribute 'startswith'

# %%
weather_flights_x_sf_sorted.info()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Plot flight date and snowfall by flight cancellation status
sns.barplot(x='flight_date', y='snow', hue='cancelled', data=weather_flights_x_sf_sorted)
plt.title('Snowfall by Flight Cancellation Status')
plt.xlabel('Flight Date')
plt.ylabel('Snowfall')
plt.xticks(rotation=90)
plt.show()

# %%
# Barplot for windspeed per day by origin
f2 = sns.barplot(x=weather_flights_x_sf_sorted['flight_date'], y=weather_flights_x_sf_sorted['windspeed'], hue=weather_flights_x_sf_sorted['cancelled'], ax=ax[1])
f2.tick_params(axis='x', labelrotation=90)  # sets the label y-axis
f2.set(xlabel=None)  # sets the x-axis label
f2.set_ylabel("Windspeed in km/h", fontsize=10)  # sets the y-axis label
f2.set_title("Windspeed per day", fontsize=15)  # sets title for subplot

# Barplot for average temperature per day by origin
f3 = sns.barplot(x=weather_flights_x_sf_sorted['flight_date'], y=weather_flights_x_sf_sorted['averg_temp'], hue=weather_flights_x_sf_sorted['cancelled'], ax=ax[2])
f3.tick_params(axis='x', labelrotation=90)  # sets the label y-axis
f3.set(xlabel=None)  # sets the x-axis label
f3.set_ylabel("Average temperature in Celcius", fontsize=10)  # sets the y-axis label
f3.set_title("Average temperature per day", fontsize=15)  # sets title for subplot

plt.show()

# %%
weather_flights_x_sf_sorted['cancelled']

# %%
weather_flights_x_sf_sorted.info()

# %%
# Calculate correlation coefficients between flight cancellations and weather conditions
correlation_cancelled_snow = weather_flights_x_sf_sorted['cancelled'].corr(weather_flights_x_sf_sorted['snow'])
correlation_cancelled_windspeed = weather_flights_x_sf_sorted['cancelled'].corr(weather_flights_x_sf_sorted['windspeed'])
correlation_cancelled_averg_temp = weather_flights_x_sf_sorted['cancelled'].corr(weather_flights_x_sf_sorted['averg_temp'])

print("Correlation between flight cancellations and snow:", correlation_cancelled_snow)
print("Correlation between flight cancellations and windspeed:", correlation_cancelled_windspeed)
print("Correlation between flight cancellations and average temperature:", correlation_cancelled_averg_temp)

# %%
weather_flights_x_sf_sorted['cancelled']

# %%
weather_flights_x_sf.plot(kind='scatter', x='cancelled', y='snow');

# %%
sns.barplot(x='cancelled', y='snow', hue= 'origin', data=weather_flights_x_sf_sorted, estimator = "mean")
plt.title('Mean Snow by flight cancellation status')
plt.ylabel('Mean amount of snow in mm')
plt.xlabel('Flight cancellation status')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Filter DataFrame for a specific origin
origin_filter = 'JFK'  # Replace 'your_origin_value' with the origin you want to filter for
filtered_data = weather_flights_x_sf_sorted[weather_flights_x_sf_sorted['origin'] == origin_filter]

# Plot flight date and snowfall by flight cancellation status for the filtered data
sns.barplot(x='flight_date', y='snow', hue='cancelled', data=filtered_data)
plt.title(f'Snowfall by Flight Cancellation Status for Origin {origin_filter}')
plt.xlabel('Flight Date')
plt.ylabel('Snowfall')
plt.xticks(rotation=90)
plt.show()

# %%
weather_flights_x_sf_sorted.origin

# %%
sns.catplot(data=weather_flights_x_sf_sorted, x="cancelled", y="snow", hue="origin", kind="bar")

# %%
sns.catplot(data=weather_flights_x_sf_sorted, x="cancelled", y="snow", hue="origin", kind="bar")

# %%
sns.catplot(data=weather_flights_x_sf_sorted, x="cancelled", y="windspeed", hue="origin", kind="bar")

# %%
sns.catplot(data=weather_flights_x_sf_sorted, x="cancelled", y="averg_temp", hue="origin", kind="bar")

# %%
sns.displot(weather_flights_x_sf_sorted, x="cancelled", hue="origin", multiple="stack")

# %%
g = sns.catplot(
    data=weather_flights_x_sf_sorted,
    x="snow", y="origin", row="cancelled",
    kind="box", orient="h",
    sharex=False, margin_titles=True,
    height=5.5, aspect=9,
)
g.set(xlabel="Snow in mm", ylabel="")
g.set_titles(row_template="{row_name} cancellation")

# %%
sns.catplot(
    data=weather_flights_x_sf_sorted, x="origin", y="snow", #hue="canceled",
    kind="swarm", col="cancelled", aspect=.2,
)

# %%
g = sns.FacetGrid(weather_flights_x_sf_sorted, col="origin", height=4, aspect=.5)
g.map(sns.barplot, "cancelled", "snow", )

# %%
# Calculate correlation coefficients between flight cancellations and weather conditions
correlation_cancelled_snow = weather_flights_x_sf_sorted['cancelled'].corr(weather_flights_x_sf_sorted['snow'])
correlation_cancelled_windspeed = weather_flights_x_sf_sorted['cancelled'].corr(weather_flights_x_sf_sorted['windspeed'])
correlation_cancelled_averg_temp = weather_flights_x_sf_sorted['cancelled'].corr(weather_flights_x_sf_sorted['averg_temp'])

print("Correlation between flight cancellations and snow:", correlation_cancelled_snow)
print("Correlation between flight cancellations and windspeed:", correlation_cancelled_windspeed)
print("Correlation between flight cancellations and average temperature:", correlation_cancelled_averg_temp)

# %%
import scipy.stats as stats

# Filter DataFrame for origin = JFK
jfk_data = weather_flights_x_sf_sorted[weather_flights_x_sf_sorted['origin'] == 'JFK']

# Calculate point-biserial correlation coefficient between cancellation status and amount of snow
correlation_coefficient, p_value = stats.pointbiserialr(jfk_data['cancelled'], jfk_data['snow'])

print(f"Point-biserial correlation coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

# %%
import scipy.stats as stats

# Filter DataFrame for origin = JFK
iad_data = weather_flights_x_sf_sorted[weather_flights_x_sf_sorted['origin'] == 'IAD']

# Calculate point-biserial correlation coefficient between cancellation status and amount of snow
correlation_coefficient, p_value = stats.pointbiserialr(jfk_data['cancelled'], jfk_data['snow'])

print(f"Point-biserial correlation coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

# %%
import scipy.stats as stats

# Filter DataFrame for origin = JFK
phl_data = weather_flights_x_sf[weather_flights_x_sf['origin'] == 'PHL']

# Calculate point-biserial correlation coefficient between cancellation status and amount of snow
correlation_coefficient, p_value = stats.pointbiserialr(jfk_data['cancelled'], jfk_data['snow'])

print(f"Point-biserial correlation coefficient: {correlation_coefficient}")
print(f"P-value: {p_value}")

# %%
import scipy.stats as stats

# Calculate point-biserial correlation coefficient for each numerical variable
for col in ["snow", "windspeed", "averg_temp"]:
    correlation_coefficient, p_value = stats.pointbiserialr(weather_flights_x_sf_sorted['cancelled'], weather_flights_x_sf_sorted[col])
    print(f"Point-biserial correlation coefficient between 'cancelled' and '{col}': {correlation_coefficient}")
    print(f"P-value: {p_value}\n")

# %%
g = sns.FacetGrid(weather_flights_x_sf_sorted, col="origin", height=4, aspect=.5)
g.map(sns.barplot, "cancelled", "windspeed", )

# %%
g = sns.FacetGrid(weather_flights_x_sf_sorted, col="origin", height=4, aspect=.5)
g.map(sns.barplot, "cancelled", "averg_temp", )

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define custom function to add labels with count of cancelled flights
def add_labels(ax, **kwargs):
    cancelled_counts = df['cancelled'].value_counts()
    for idx, count in enumerate(cancelled_counts):
        ax.text(idx, count, str(count), ha='center', va='bottom')

# Create FacetGrid
g = sns.FacetGrid(weather_flights_x_sf_sorted, col="origin", height=4, aspect=.5)

# Map barplot with custom function
g.map_dataframe(sns.barplot, "cancelled", "snow")

# Add labels with count of cancelled flights
g.map_dataframe(add_labels)

# Set plot titles
g.set_titles(col_template="{col_name}")

plt.show()
