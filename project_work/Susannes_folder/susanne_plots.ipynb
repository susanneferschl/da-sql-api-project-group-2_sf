# %%
from sql_functions import get_dataframe
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as

# %%
schema = 'hh_analytics_24_1'

sql_query = f'SELECT * FROM {schema}.flights_group_x_sf'
flights = get_dataframe(sql_query)

flights.head(20)
# Out:
#    flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0   2010-02-02    1825.0            1830       -5.0    1926.0            1945
# 1   2010-02-02    1047.0            1025       22.0    1153.0            1135
# 2   2010-02-02    1331.0            1335       -4.0    1434.0            1445
# 3   2010-02-02     638.0             630        8.0     749.0             740
# 4   2010-02-02     949.0             955       -6.0    1453.0            1515
# 5   2010-02-02    1802.0            1805       -3.0    2320.0            2320
# 6   2010-02-02    1339.0            1345       -6.0    1841.0            1900
# 7   2010-02-02     908.0             910       -2.0    1424.0            1455
# 8   2010-02-02    1800.0            1805       -5.0    2318.0            2335
# 9   2010-02-02    1248.0            1245        3.0    1813.0            1830
# 10  2010-02-02    1632.0            1620       12.0    1803.0            1745
# 11  2010-02-02    1045.0            1030       15.0    1206.0            1200
# 12  2010-02-02     735.0             740       -5.0     853.0             910
# 13  2010-02-02    1431.0            1430        1.0    1653.0            1715
# 14  2010-02-02     734.0             735       -1.0     946.0            1010
# 15  2010-02-02    1736.0            1740       -4.0    2005.0            2015
# 16  2010-02-02    1107.0            1110       -3.0    1325.0            1345
# 17  2010-02-02     856.0             900       -4.0    1125.0            1150
# 18  2010-02-02    1333.0            1305       28.0    1556.0            1605
# 19  2010-02-02    1913.0            1845       28.0    2147.0            2130
#
#     arr_delay airline tail_number  flight_number  ... air_time  \
# 0       -19.0      WN      N257WN            484  ...     50.0
# 1        18.0      WN      N308SA            801  ...     52.0
# 2       -11.0      WN      N751SW           1480  ...     52.0
# 3         9.0      WN      N942WN           3137  ...     50.0
# 4       -22.0      WN      N799SW            146  ...    173.0
# 5         0.0      WN      N401WN            204  ...    175.0
# 6       -19.0      WN      N743SW            242  ...    170.0
# 7       -31.0      WN      N927WN           1305  ...    183.0
# 8       -17.0      WN      N225WN           2539  ...    181.0
# 9       -17.0      WN      N792SW           3397  ...    172.0
# 10       18.0      WN      N665WN            213  ...     65.0
# 11        6.0      WN      N370SW           1758  ...     63.0
# 12      -17.0      WN      N688SW           1922  ...     65.0
# 13      -22.0      WN      N386SW              9  ...    123.0
# 14      -24.0      WN      N451WN            214  ...    116.0
# 15      -10.0      WN      N688SW           1610  ...    127.0
# 16      -20.0      WN      N205WN           1942  ...    121.0
# 17      -25.0      WN      N503SW            644  ...    131.0
# 18       -9.0      WN      N629SW           2441  ...    126.0
# 19       17.0      WN      N383SW           3855  ...    138.0
#
#    actual_elapsed_time  distance  cancelled  diverted        lat         lon  \
# 0                 61.0     336.0          0         0  39.998001  -82.891899
# 1                 66.0     336.0          0         0  39.998001  -82.891899
# 2                 63.0     336.0          0         0  39.998001  -82.891899
# 3                 71.0     336.0          0         0  39.998001  -82.891899
# 4                184.0    1491.0          0         0  39.861698 -104.672997
# 5                198.0    1491.0          0         0  39.861698 -104.672997
# 6                182.0    1491.0          0         0  39.861698 -104.672997
# 7                196.0    1557.0          0         0  39.861698 -104.672997
# 8                198.0    1557.0          0         0  39.861698 -104.672997
# 9                205.0    1557.0          0         0  39.861698 -104.672997
# 10                91.0     408.0          0         0  42.212399  -83.353401
# 11                81.0     408.0          0         0  42.212399  -83.353401
# 12                78.0     408.0          0         0  42.212399  -83.353401
# 13               142.0     925.0          0         0  26.072599  -80.152702
# 14               132.0     925.0          0         0  26.072599  -80.152702
# 15               149.0     925.0          0         0  26.072599  -80.152702
# 16               138.0     925.0          0         0  26.072599  -80.152702
# 17               149.0     992.0          0         0  26.072599  -80.152702
# 18               143.0     992.0          0         0  26.072599  -80.152702
# 19               154.0     992.0          0         0  26.072599  -80.152702
#
#                city  tz_origin tz_dest
# 0          Columbus       -5.0    -5.0
# 1          Columbus       -5.0    -5.0
# 2          Columbus       -5.0    -5.0
# 3          Columbus       -5.0    -5.0
# 4            Denver       -7.0    -5.0
# 5            Denver       -7.0    -5.0
# 6            Denver       -7.0    -5.0
# 7            Denver       -7.0    -5.0
# 8            Denver       -7.0    -5.0
# 9            Denver       -7.0    -5.0
# 10          Detroit       -5.0    -5.0
# 11          Detroit       -5.0    -5.0
# 12          Detroit       -5.0    -5.0
# 13  Fort Lauderdale       -5.0    -5.0
# 14  Fort Lauderdale       -5.0    -5.0
# 15  Fort Lauderdale       -5.0    -5.0
# 16  Fort Lauderdale       -5.0    -5.0
# 17  Fort Lauderdale       -5.0    -5.0
# 18  Fort Lauderdale       -5.0    -5.0
# 19  Fort Lauderdale       -5.0    -5.0
#
# [20 rows x 22 columns]

# %%
flights.columns
# Out:
# Index(['flight_date', 'dep_time', 'sched_dep_time', 'dep_delay', 'arr_time',
#        'sched_arr_time', 'arr_delay', 'airline', 'tail_number',
#        'flight_number', 'origin', 'dest', 'air_time', 'actual_elapsed_time',
#        'distance', 'cancelled', 'diverted', 'lat', 'lon', 'city', 'tz_origin',
#        'tz_dest'],
#       dtype='object')

# %%
flights['flight_date'] = pd.to_datetime(flights['flight_date'])

# Group by flight_date and aggregate counts of cancelled and diverted flights
agg_flights = flights.groupby(['origin', 'flight_date']).agg({'cancelled': 'sum', 'diverted': 'sum'}).reset_index()


# Plot the counts
plt.figure(figsize=(10, 6))
plt.plot(agg_flights['origin', 'flight_date'], agg_flights['cancelled'], label='Cancelled Flights', marker='o')
plt.plot(agg_flights['origin', 'flight_date'], agg_flights['diverted'], label='Diverted Flights', marker='o')

# Add labels and title
plt.xlabel('Flight Date')
plt.ylabel('Count')
plt.title('Count of Cancelled and Diverted Flights by Flight Date and origin')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Show plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('origin', 'flight_date')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 9
#       7 # Plot the counts
#       8 plt.figure(figsize=(10, 6))
# ----> 9 plt.plot(agg_flights['origin', 'flight_date'], agg_flights['cancelled'], label='Cancelled Flights', marker='o')
#      10 plt.plot(agg_flights['origin', 'flight_date'], agg_flights['diverted'], label='Diverted Flights', marker='o')
#      12 # Add labels and title
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ('origin', 'flight_date')
