# %% [markdown]
# ## Packages and functions required

# %%
# Import all necessary libraries
import pandas as pd
import numpy as np
import psycopg2 # needed to get database exception errors when uploading dataframe
import requests # package for getting data from the web
from zipfile import * # package for unzipping zip files
import os

# %%
# Import the get_engine function from our sql_functions.
from sql_functions import get_engine #adjust this as necessary to match your sql_functions.py connection methods

# %%
# Specifies path for saving file
path ='data/' 
# Create the data folder
# !mkdir {path}
# Out:
# mkdir: data/: File exists

# %%
# function to get specified csv file from the website https://transtats.bts.gov

def download_data(year, month ):
    # Get the file from the website https://transtats.bts.gov
    zip_file = f'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_{year}_{month}.zip'
    url = (f'https://transtats.bts.gov/PREZIP/{zip_file}')
    # Download the database
    r = requests.get(f'{url}', verify=False)
    # Save database to local file storage
    with open(path+zip_file, 'wb') as f:
        f.write(r.content)
        print(f'--> zip_file with name: {zip_file} downloaded succesfully.' )

# %%
# function to get specified csv file from the website https://transtats.bts.gov

def download_data(year, month ):
    # Get the file from the website https://transtats.bts.gov
    zip_file = f'On_Time_Reporting_Carrier_On_Time_Performance_1987_present_{year}_{month}.zip'
    url = (f'https://transtats.bts.gov/PREZIP/{zip_file}')
    # Download the database
    r = requests.get(f'{url}', verify=False)
    # Save database to local file storage
    with open(path+zip_file, 'wb') as f:
        f.write(r.content)
        print(f'--> zip_file with name: {zip_file} downloaded succesfully.' )

# %% [markdown]
# ## df_flights_2010_2

# %%
years_list = [2010] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2010_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2010_2.csv'

# Read in your data
df_flights_2010_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2010_2.shape)
display(df_flights_2010_2.head())
# Out:
# (483270, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2010        1      2           2          2  2010-02-02                WN
# 1  2010        1      2           2          2  2010-02-02                WN
# 2  2010        1      2           2          2  2010-02-02                WN
# 3  2010        1      2           2          2  2010-02-02                WN
# 4  2010        1      2           2          2  2010-02-02                WN
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19393                          WN      N907WN  ...
# 1                     19393                          WN      N270WN  ...
# 2                     19393                          WN      N357SW  ...
# 3                     19393                          WN      N918WN  ...
# 4                     19393                          WN      N355SW  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
# Columns from downloaded file that are to be kept
columns_to_keep = [
                'FlightDate',
                'DepTime',
                'CRSDepTime',
                'DepDelay',
                'ArrTime',
                'CRSArrTime',
                'ArrDelay',
                'Reporting_Airline',
                'Tail_Number',
                'Flight_Number_Reporting_Airline',
                'Origin',
                'Dest',
                'AirTime',
                'ActualElapsedTime',
                'Distance',
                'Cancelled',
                'Diverted'
]

# %% [markdown]
# ## df_flights_2011_2

# %%
years_list = [2011] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2011_2.csv'

# Read in your data
df_flights_2011_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2011_2.shape)
display(df_flights_2011_2.head())
# Out:
# (455516, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2011        1      2           1          2  2011-02-01                AA
# 1  2011        1      2           2          3  2011-02-02                AA
# 2  2011        1      2           3          4  2011-02-03                AA
# 3  2011        1      2           4          5  2011-02-04                AA
# 4  2011        1      2           5          6  2011-02-05                AA
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19805                          AA      N323AA  ...
# 1                     19805                          AA      N335AA  ...
# 2                     19805                          AA      N323AA  ...
# 3                     19805                          AA      N338AA  ...
# 4                     19805                          AA      N323AA  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2011        1      2           1          2  2011-02-01
# 1       2011        1      2           2          3  2011-02-02
# 2       2011        1      2           3          4  2011-02-03
# 3       2011        1      2           4          5  2011-02-04
# 4       2011        1      2           5          6  2011-02-05
# ...      ...      ...    ...         ...        ...         ...
# 455511  2011        1      2           7          1  2011-02-07
# 455512  2011        1      2          22          2  2011-02-22
# 455513  2011        1      2          20          7  2011-02-20
# 455514  2011        1      2          21          1  2011-02-21
# 455515  2011        1      2          25          5  2011-02-25
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                     AA                     19805
# 1                     AA                     19805
# 2                     AA                     19805
# 3                     AA                     19805
# 4                     AA                     19805
# ...                  ...                       ...
# 455511                OO                     20304
# 455512                OO                     20304
# 455513                OO                     20304
# 455514                OO                     20304
# 455515                OO                     20304
#
#        IATA_CODE_Reporting_Airline Tail_Number  ...  Div4TailNum  Div5Airport  \
# 0                               AA      N323AA  ...          NaN          NaN
# 1                               AA      N335AA  ...          NaN          NaN
# 2                               AA      N323AA  ...          NaN          NaN
# 3                               AA      N338AA  ...          NaN          NaN
# 4                               AA      N323AA  ...          NaN          NaN
# ...                            ...         ...  ...          ...          ...
# 455511                          OO      N224SW  ...          NaN          NaN
# 455512                          OO      N301YV  ...          NaN          NaN
# 455513                          OO      N295SW  ...          NaN          NaN
# 455514                          OO      N561SW  ...          NaN          NaN
# 455515                          OO      N298SW  ...          NaN          NaN
#
#         Div5AirportID  Div5AirportSeqID Div5WheelsOn Div5TotalGTime  \
# 0                 NaN               NaN          NaN            NaN
# 1                 NaN               NaN          NaN            NaN
# 2                 NaN               NaN          NaN            NaN
# 3                 NaN               NaN          NaN            NaN
# 4                 NaN               NaN          NaN            NaN
# ...               ...               ...          ...            ...
# 455511            NaN               NaN          NaN            NaN
# 455512            NaN               NaN          NaN            NaN
# 455513            NaN               NaN          NaN            NaN
# 455514            NaN               NaN          NaN            NaN
# 455515            NaN               NaN          NaN            NaN
#
#        Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0                   NaN            NaN         NaN           NaN
# 1                   NaN            NaN         NaN           NaN
# 2                   NaN            NaN         NaN           NaN
# 3                   NaN            NaN         NaN           NaN
# 4                   NaN            NaN         NaN           NaN
# ...                 ...            ...         ...           ...
# 455511              NaN            NaN         NaN           NaN
# 455512              NaN            NaN         NaN           NaN
# 455513              NaN            NaN         NaN           NaN
# 455514              NaN            NaN         NaN           NaN
# 455515              NaN            NaN         NaN           NaN
#
# [455516 rows x 110 columns]

# %%
# Columns from downloaded file that are to be kept
columns_to_keep = [
                'FlightDate',
                'DepTime',
                'CRSDepTime',
                'DepDelay',
                'ArrTime',
                'CRSArrTime',
                'ArrDelay',
                'Reporting_Airline',
                'Tail_Number',
                'Flight_Number_Reporting_Airline',
                'Origin',
                'Dest',
                'AirTime',
                'ActualElapsedTime',
                'Distance',
                'Cancelled',
                'Diverted'
]

# %% [markdown]
# ## df_flights_2012_2

# %%
years_list = [2012] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2012_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2012_2.csv'

# Read in your data
df_flights_2012_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2012_2.shape)
display(df_flights_2012_2.head())
# Out:
# (464826, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2012        1      2           1          3  2012-02-01                AA
# 1  2012        1      2           2          4  2012-02-02                AA
# 2  2012        1      2           3          5  2012-02-03                AA
# 3  2012        1      2           4          6  2012-02-04                AA
# 4  2012        1      2           5          7  2012-02-05                AA
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19805                          AA      N323AA  ...
# 1                     19805                          AA      N325AA  ...
# 2                     19805                          AA      N323AA  ...
# 3                     19805                          AA      N329AA  ...
# 4                     19805                          AA      N319AA  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
# Columns from downloaded file that are to be kept
columns_to_keep = [
                'FlightDate',
                'DepTime',
                'CRSDepTime',
                'DepDelay',
                'ArrTime',
                'CRSArrTime',
                'ArrDelay',
                'Reporting_Airline',
                'Tail_Number',
                'Flight_Number_Reporting_Airline',
                'Origin',
                'Dest',
                'AirTime',
                'ActualElapsedTime',
                'Distance',
                'Cancelled',
                'Diverted'
]

# %% [markdown]
# ## df_flights_2013_2

# %%
years_list = [2013] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2013_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2013_2.csv'

# Read in your data
df_flights_2013_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2013_2.shape)
display(df_flights_2013_2.head())
# Out:
# (469746, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2013        1      2          17          7  2013-02-17                DL
# 1  2013        1      2          17          7  2013-02-17                DL
# 2  2013        1      2          17          7  2013-02-17                DL
# 3  2013        1      2          17          7  2013-02-17                DL
# 4  2013        1      2          17          7  2013-02-17                DL
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19790                          DL      N718TW  ...
# 1                     19790                          DL      N667DN  ...
# 2                     19790                          DL      N614DL  ...
# 3                     19790                          DL      N613DL  ...
# 4                     19790                          DL      N922DL  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
# Columns from downloaded file that are to be kept
columns_to_keep = [
                'FlightDate',
                'DepTime',
                'CRSDepTime',
                'DepDelay',
                'ArrTime',
                'CRSArrTime',
                'ArrDelay',
                'Reporting_Airline',
                'Tail_Number',
                'Flight_Number_Reporting_Airline',
                'Origin',
                'Dest',
                'AirTime',
                'ActualElapsedTime',
                'Distance',
                'Cancelled',
                'Diverted'
]

# %% [markdown]
# ## df_flights_2014_2

# %%
years_list = [2014] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2014_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2014_2.csv'

# Read in your data
df_flights_2014_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2014_2.shape)
display(df_flights_2014_2.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[148], line 5
#       2 csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2014_2.csv'
#       4 # Read in your data
# ----> 5 df_flights_2014_2 = pd.read_csv(path+csv_file, low_memory = False)
#       6 display(df_flights_2014_2.shape)
#       7 display(df_flights_2014_2.head())
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/parsers/readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:230, in CParserWrapper.read(self, nrows)
#     227         data = _concatenate_chunks(chunks)
#     229     else:
# --> 230         data = self._reader.read(nrows)
#     231 except StopIteration:
#     232     if self._first_chunk:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:787, in pandas._libs.parsers.TextReader.read()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:876, in pandas._libs.parsers.TextReader._read_rows()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %% [markdown]
# ## df_flights_2015_2

# %%
years_list = [2015] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2015_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2015_2.csv'

# Read in your data
df_flights_2015_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2015_2.shape)
display(df_flights_2015_2.head())
# Out:
# (429191, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2015        1      2           7          6  2015-02-07                AS
# 1  2015        1      2           7          6  2015-02-07                AS
# 2  2015        1      2           7          6  2015-02-07                AS
# 3  2015        1      2           7          6  2015-02-07                AS
# 4  2015        1      2           7          6  2015-02-07                AS
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19930                          AS      N618AS  ...
# 1                     19930                          AS      N778AS  ...
# 2                     19930                          AS      N586AS  ...
# 3                     19930                          AS      N615AS  ...
# 4                     19930                          AS      N471AS  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# ## df_flights_2016_2

# %%
years_list = [2016] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2016_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2016_2.csv'

# Read in your data
df_flights_2016_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2016_2.shape)
display(df_flights_2016_2.head())
# Out:
# (423889, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2016        1      2           3          3  2016-02-03                AA
# 1  2016        1      2           4          4  2016-02-04                AA
# 2  2016        1      2           5          5  2016-02-05                AA
# 3  2016        1      2           6          6  2016-02-06                AA
# 4  2016        1      2           7          7  2016-02-07                AA
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19805                          AA      N484AA  ...
# 1                     19805                          AA      N493AA  ...
# 2                     19805                          AA      N4UBAA  ...
# 3                     19805                          AA      N466AA  ...
# 4                     19805                          AA      N590AA  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# ## df_flights_2017_2

# %%
years_list = [2017] # List of years from 2011 to 2021
months_list = [2]  # List of months containing only February

# Download flights data as zipfile(s)
# We use a nested loop to specify the years and months to define the range of the data we would like to have 
for year in years_list:
    for month in months_list:
        download_data(year, month)
        extract_zip(year, month)
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/urllib3/connectionpool.py:1103: InsecureRequestWarning: Unverified HTTPS request is being made to host 'transtats.bts.gov'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# --> zip_file with name: On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2017_2.zip downloaded succesfully.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 9
#       7 for month in months_list:
#       8     download_data(year, month)
# ----> 9     extract_zip(year, month)
#
# NameError: name 'extract_zip' is not defined

# %%
# define the name of the csv file you want to read in
csv_file = 'On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2017_2.csv'

# Read in your data
df_flights_2017_2 = pd.read_csv(path+csv_file, low_memory = False)
display(df_flights_2017_2.shape)
display(df_flights_2017_2.head())
# Out:
# (410517, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2017        1      2           1          3  2017-02-01                F9
# 1  2017        1      2           1          3  2017-02-01                F9
# 2  2017        1      2           1          3  2017-02-01                F9
# 3  2017        1      2           1          3  2017-02-01                F9
# 4  2017        1      2           1          3  2017-02-01                F9
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     20436                          F9      N202FR  ...
# 1                     20436                          F9      N202FR  ...
# 2                     20436                          F9      N202FR  ...
# 3                     20436                          F9      N203FR  ...
# 4                     20436                          F9      N203FR  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %% [markdown]
# ## Merging into flights_2010_to_2017

# %%
# List of your DataFrames
dfs = [
    df_flights_2010_2,
    df_flights_2011_2,
    df_flights_2012_2,
    df_flights_2013_2,
    df_flights_2014_2,
    df_flights_2015_2,
    df_flights_2016_2,
    df_flights_2017_2
]

# Concatenate the DataFrames vertically
df = pd.concat(dfs, ignore_index=True)

# Optionally, you can reset the index
# flights_2010_to_2017.reset_index(drop=True, inplace=True)

# Display the shape and the first few rows of the concatenated DataFrame
print(df.shape)
print(df.head())
# Out:
# (3567557, 110)
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate Reporting_Airline  \
# 0  2010        1      2           2          2  2010-02-02                WN
# 1  2010        1      2           2          2  2010-02-02                WN
# 2  2010        1      2           2          2  2010-02-02                WN
# 3  2010        1      2           2          2  2010-02-02                WN
# 4  2010        1      2           2          2  2010-02-02                WN
#
#    DOT_ID_Reporting_Airline IATA_CODE_Reporting_Airline Tail_Number  ...  \
# 0                     19393                          WN      N907WN  ...
# 1                     19393                          WN      N270WN  ...
# 2                     19393                          WN      N357SW  ...
# 3                     19393                          WN      N918WN  ...
# 4                     19393                          WN      N355SW  ...
#
#    Div4TailNum  Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 0          NaN          NaN            NaN               NaN          NaN
# 1          NaN          NaN            NaN               NaN          NaN
# 2          NaN          NaN            NaN               NaN          NaN
# 3          NaN          NaN            NaN               NaN          NaN
# 4          NaN          NaN            NaN               NaN          NaN
#
#   Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  Unnamed: 109
# 0            NaN              NaN            NaN         NaN           NaN
# 1            NaN              NaN            NaN         NaN           NaN
# 2            NaN              NaN            NaN         NaN           NaN
# 3            NaN              NaN            NaN         NaN           NaN
# 4            NaN              NaN            NaN         NaN           NaN
#
# [5 rows x 110 columns]

# %%
df.tail()
# Out:
#          Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 3567552  2017        1      2          20          1  2017-02-20
# 3567553  2017        1      2          20          1  2017-02-20
# 3567554  2017        1      2          20          1  2017-02-20
# 3567555  2017        1      2          20          1  2017-02-20
# 3567556  2017        1      2          20          1  2017-02-20
#
#         Reporting_Airline  DOT_ID_Reporting_Airline  \
# 3567552                OO                     20304
# 3567553                OO                     20304
# 3567554                OO                     20304
# 3567555                OO                     20304
# 3567556                OO                     20304
#
#         IATA_CODE_Reporting_Airline Tail_Number  ...  Div4TailNum  \
# 3567552                          OO      N440SW  ...          NaN
# 3567553                          OO      N675BR  ...          NaN
# 3567554                          OO      N899SK  ...          NaN
# 3567555                          OO      N679CA  ...          NaN
# 3567556                          OO      N679CA  ...          NaN
#
#          Div5Airport  Div5AirportID  Div5AirportSeqID Div5WheelsOn  \
# 3567552          NaN            NaN               NaN          NaN
# 3567553          NaN            NaN               NaN          NaN
# 3567554          NaN            NaN               NaN          NaN
# 3567555          NaN            NaN               NaN          NaN
# 3567556          NaN            NaN               NaN          NaN
#
#         Div5TotalGTime Div5LongestGTime  Div5WheelsOff Div5TailNum  \
# 3567552            NaN              NaN            NaN         NaN
# 3567553            NaN              NaN            NaN         NaN
# 3567554            NaN              NaN            NaN         NaN
# 3567555            NaN              NaN            NaN         NaN
# 3567556            NaN              NaN            NaN         NaN
#
#          Unnamed: 109
# 3567552           NaN
# 3567553           NaN
# 3567554           NaN
# 3567555           NaN
# 3567556           NaN
#
# [5 rows x 110 columns]

# %%
# Columns from downloaded file that are to be kept
columns_to_keep = [
                'FlightDate',
                'DepTime',
                'CRSDepTime',
                'DepDelay',
                'ArrTime',
                'CRSArrTime',
                'ArrDelay',
                'Reporting_Airline',
                'Tail_Number',
                'Flight_Number_Reporting_Airline',
                'Origin',
                'Dest',
                'AirTime',
                'ActualElapsedTime',
                'Distance',
                'Cancelled',
                'Diverted'
]

# %%
# Import the get_engine function from our sql_functions.
from sql_functions import get_engine #adjust this as necessary to match your sql_functions.py connection methods

# %%
# The columns in the database have different naming as in the source csv files. Lets get the names from the database

schema = 'hh_analytics_24_1' # UPDATE 'TABLE_SCHEMA' based on schema used in class 
engine = get_engine() # assign engine to be able to query against the database

table_name_sql = f'''SELECT COLUMN_NAME 
                    FROM INFORMATION_SCHEMA.COLUMNS 
                    WHERE TABLE_NAME = 'flights'
                    AND TABLE_SCHEMA ='{schema}'
                    ORDER BY ordinal_position'''
c_names = engine.execute(table_name_sql).fetchall()
c_names
# Out:
# [('flight_date',),
#  ('dep_time',),
#  ('sched_dep_time',),
#  ('dep_delay',),
#  ('arr_time',),
#  ('sched_arr_time',),
#  ('arr_delay',),
#  ('airline',),
#  ('tail_number',),
#  ('flight_number',),
#  ('origin',),
#  ('dest',),
#  ('air_time',),
#  ('actual_elapsed_time',),
#  ('distance',),
#  ('cancelled',),
#  ('diverted',)]

# %%
# we can clean up the results into a clean list
new_column_names=[]
for name in c_names:
    new_column_names.append(name[0])
new_column_names
# Out:
# ['flight_date',
#  'dep_time',
#  'sched_dep_time',
#  'dep_delay',
#  'arr_time',
#  'sched_arr_time',
#  'arr_delay',
#  'airline',
#  'tail_number',
#  'flight_number',
#  'origin',
#  'dest',
#  'air_time',
#  'actual_elapsed_time',
#  'distance',
#  'cancelled',
#  'diverted']

# %%
def clean_airline_df(df):
    '''
    Transforms a df made from BTS csv file into a df that is ready to be uploaded to SQL
    Set rows=0 for no filtering
    '''

    # Build dataframe including only the columns you want to keep
    df_airline = df.loc[:,columns_to_keep]
     
    # Clean data types and NULLs
    df_airline['FlightDate']= pd.to_datetime(df_airline['FlightDate'], yearfirst=True)
    df_airline['CRSArrTime']= pd.to_numeric(df_airline['CRSArrTime'], downcast='integer', errors='coerce')
    df_airline['Cancelled']= pd.to_numeric(df_airline['Cancelled'], downcast='integer')
    df_airline['Diverted']= pd.to_numeric(df_airline['Diverted'], downcast='integer')
    df_airline['ActualElapsedTime']= pd.to_numeric(df_airline['ActualElapsedTime'], downcast='integer', errors='coerce')
    
    # Rename columns
    df_airline.columns = new_column_names
    
    return df_airline

# %%
# Call function and check resulting dataframe
df_clean = clean_airline_df(df)
df_clean.head()
# Out:
#   flight_date  dep_time  sched_dep_time  dep_delay  arr_time  sched_arr_time  \
# 0  2010-02-02     830.0             830        0.0     842.0             900
# 1  2010-02-02    1129.0            1135       -6.0    1134.0            1200
# 2  2010-02-02    1424.0            1420        4.0    1443.0            1440
# 3  2010-02-02     625.0             635      -10.0     639.0             705
# 4  2010-02-02    1930.0            1820       70.0    1933.0            1845
#
#    arr_delay airline tail_number  flight_number origin dest  air_time  \
# 0      -18.0      WN      N907WN            334    CLE  MDW      60.0
# 1      -26.0      WN      N270WN            356    CLE  MDW      55.0
# 2        3.0      WN      N357SW            967    CLE  MDW      54.0
# 3      -26.0      WN      N918WN           1945    CLE  MDW      61.0
# 4       48.0      WN      N355SW           2624    CLE  MDW      51.0
#
#    actual_elapsed_time  distance  cancelled  diverted
# 0                 72.0     307.0          0         0
# 1                 65.0     307.0          0         0
# 2                 79.0     307.0          0         0
# 3                 74.0     307.0          0         0
# 4                 63.0     307.0          0         0

# %%
# Specify the airports you are interested in and put them as a list in the function.
def select_airport(df, airports):
    ''' Helper function for filtering the airline dataframe for a subset of airports'''
    df_out = df.loc[(df.origin.isin(airports)) | (df.dest.isin(airports))]
    return df_out

# %%
# Execute function, filtering for New York area airports
airports=['DCA', 'IAD', 'BWI', 'PHL', 'EWR', 'JFK', 'LGA']
if len(airports) > 0:
    df_selected_airports = select_airport(df_clean, airports)
else:
    df_selected_airports = df_clean
    
df_selected_airports.tail()
# Out:
#         flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 3566986  2017-02-19    1412.0            1400       12.0    1653.0
# 3566991  2017-02-19    1922.0            1905       17.0    2054.0
# 3567281  2017-02-20    2005.0            1900       65.0    2137.0
# 3567282  2017-02-20    1554.0            1515       39.0    1921.0
# 3567503  2017-02-20     756.0             800       -4.0    1018.0
#
#          sched_arr_time  arr_delay airline tail_number  flight_number origin  \
# 3566986            1656       -3.0      OO      N113SY           5960    ORD
# 3566991            2100       -6.0      OO      N154SY           5968    LGA
# 3567281            2040       57.0      OO      N738SK           3093    EWR
# 3567282            1818       63.0      OO      N738SK           3093    ORD
# 3567503            1014        4.0      OO      N679CA           3565    EWR
#
#         dest  air_time  actual_elapsed_time  distance  cancelled  diverted
# 3566986  DCA      80.0                101.0     612.0          0         0
# 3566991  ORD     124.0                152.0     733.0          0         0
# 3567281  ORD     115.0                152.0     719.0          0         0
# 3567282  EWR     105.0                147.0     719.0          0         0
# 3567503  MSP     164.0                202.0    1008.0          0         0

# %%
df_selected_airports
# Out:
#         flight_date  dep_time  sched_dep_time  dep_delay  arr_time  \
# 8        2010-02-02    1825.0            1830       -5.0    1926.0
# 9        2010-02-02    1047.0            1025       22.0    1153.0
# 10       2010-02-02    1331.0            1335       -4.0    1434.0
# 11       2010-02-02     638.0             630        8.0     749.0
# 176      2010-02-02     949.0             955       -6.0    1453.0
# ...             ...       ...             ...        ...       ...
# 3566986  2017-02-19    1412.0            1400       12.0    1653.0
# 3566991  2017-02-19    1922.0            1905       17.0    2054.0
# 3567281  2017-02-20    2005.0            1900       65.0    2137.0
# 3567282  2017-02-20    1554.0            1515       39.0    1921.0
# 3567503  2017-02-20     756.0             800       -4.0    1018.0
#
#          sched_arr_time  arr_delay airline tail_number  flight_number origin  \
# 8                  1945      -19.0      WN      N257WN            484    CMH
# 9                  1135       18.0      WN      N308SA            801    CMH
# 10                 1445      -11.0      WN      N751SW           1480    CMH
# 11                  740        9.0      WN      N942WN           3137    CMH
# 176                1515      -22.0      WN      N799SW            146    DEN
# ...                 ...        ...     ...         ...            ...    ...
# 3566986            1656       -3.0      OO      N113SY           5960    ORD
# 3566991            2100       -6.0      OO      N154SY           5968    LGA
# 3567281            2040       57.0      OO      N738SK           3093    EWR
# 3567282            1818       63.0      OO      N738SK           3093    ORD
# 3567503            1014        4.0      OO      N679CA           3565    EWR
#
#         dest  air_time  actual_elapsed_time  distance  cancelled  diverted
# 8        BWI      50.0                 61.0     336.0          0         0
# 9        BWI      52.0                 66.0     336.0          0         0
# 10       BWI      52.0                 63.0     336.0          0         0
# 11       BWI      50.0                 71.0     336.0          0         0
# 176      BWI     173.0                184.0    1491.0          0         0
# ...      ...       ...                  ...       ...        ...       ...
# 3566986  DCA      80.0                101.0     612.0          0         0
# 3566991  ORD     124.0                152.0     733.0          0         0
# 3567281  ORD     115.0                152.0     719.0          0         0
# 3567282  EWR     105.0                147.0     719.0          0         0
# 3567503  MSP     164.0                202.0    1008.0          0         0
#
# [730539 rows x 17 columns]

# %%
# Specify which table within your database you want to push your data to. Give your table an unambiguous name.
# Example: flights_sp for Sina's flights table, flights_groupname or similar
table_name = 'flights_2010_to_2017'
# If the specified table doesn't exist yet, it will be created
# With 'replace', your data will be replaced if the table already exists.
# This may take some time ...

# Write records stored in a dataframe to SQL database
if engine!=None:
    try:
        df_selected_airports.to_sql(name=table_name, # Name of SQL table
                        con=engine, # Engine or connection
                        if_exists='replace', # Drop the table before inserting new values 
                        schema=schema, # Use schmea that was defined earlier
                        index=False, # Write DataFrame index as a column
                        chunksize=5000, # Specify the number of rows in each batch to be written at a time
                        method='multi') # Pass multiple values in a single INSERT clause
        print(f"The {table_name} table was imported successfully.")
    # Error handling
    except (Exception, psycopg2.DatabaseError) as error:
        print(error)
        engine = None
# Out:
# The flights_2010_to_2017 table was imported successfully.

# %% [markdown]
# ## Validating Hypothesis

# %%
from sql_functions import get_dataframe
from sql_functions import get_engine
import pandas as pd
import psycopg2

# %%
#rank airports: 
schema = 'hh_analytics_24_1'
sql_query_2 = f"""
            SELECT origin
            FROM flights_group_x_rr;
"""
get_dataframe(sql_query_2)
# Out:
# ---------------------------------------------------------------------------
# UndefinedTable                            Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# UndefinedTable: relation "flights_group_x_rr" does not exist
# LINE 3:             FROM flights_group_x_rr;
#                          ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[22], line 7
#       2 schema = 'hh_analytics_24_1'
#       3 sql_query_2 = f"""
#       4             SELECT origin
#       5             FROM flights_group_x_rr;
#       6 """
# ----> 7 get_dataframe(sql_query_2)
#
# File ~/neuefische/da-sql-api-project/renans_folder/sql_functions.py:45, in get_dataframe(sql_query)
#      38  engine = sqlalchemy.create_engine('postgresql://user:pass@host/database',
#      39                      connect_args=sql_config # use dictionary with config details
#      40                      )
#      41  # open a conn session using 'with', execute the query, and return the results
#      42 #with engine.begin() as conn:
#      43  #results = conn.execute(query)
#      44  #return results.fetchall()
# ---> 45  data = pd.read_sql_query(sql=sql_query, con=engine)
#      46  return data
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/sql.py:399, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype)
#     341 """
#     342 Read SQL query into a DataFrame.
#     343
#    (...)
#     396 parameter will be converted to UTC.
#     397 """
#     398 pandas_sql = pandasSQL_builder(con)
# --> 399 return pandas_sql.read_query(
#     400     sql,
#     401     index_col=index_col,
#     402     params=params,
#     403     coerce_float=coerce_float,
#     404     parse_dates=parse_dates,
#     405     chunksize=chunksize,
#     406     dtype=dtype,
#     407 )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    1509 """
#    1510 Read SQL query into a DataFrame.
#    1511
#    (...)
#    1553
#    1554 """
#    1555 args = _convert_params(sql, params)
# -> 1557 result = self.execute(*args)
#    1558 columns = result.keys()
#    1560 if chunksize is not None:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/io/sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    1400 def execute(self, *args, **kwargs):
#    1401     """Simple passthrough to SQLAlchemy connectable"""
# -> 1402     return self.connectable.execution_options().execute(*args, **kwargs)
#
# File <string>:2, in execute(self, statement, *multiparams, **params)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/util/deprecations.py:402, in _decorate_with_warning.<locals>.warned(fn, *args, **kwargs)
#     400 if not skip_warning:
#     401     _warn_with_version(message, version, wtype, stacklevel=3)
# --> 402 return fn(*args, **kwargs)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3176, in Engine.execute(self, statement, *multiparams, **params)
#    3158 """Executes the given construct and returns a
#    3159 :class:`_engine.CursorResult`.
#    3160
#    (...)
#    3173
#    3174 """
#    3175 connection = self.connect(close_with_result=True)
# -> 3176 return connection.execute(statement, *multiparams, **params)
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    1282 if isinstance(statement, util.string_types):
#    1283     util.warn_deprecated_20(
#    1284         "Passing a string to Connection.execute() is "
#    1285         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    1288         "driver-level SQL string."
#    1289     )
# -> 1291     return self._exec_driver_sql(
#    1292         statement,
#    1293         multiparams,
#    1294         params,
#    1295         _EMPTY_EXECUTION_OPTS,
#    1296         future=False,
#    1297     )
#    1299 try:
#    1300     meth = statement._execute_on_connection
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1585         (
#    1586             statement,
#    1587             distilled_params,
#    (...)
#    1591             statement, distilled_parameters, execution_options
#    1592         )
#    1594 dialect = self.dialect
# -> 1595 ret = self._execute_context(
#    1596     dialect,
#    1597     dialect.execution_ctx_cls._init_statement,
#    1598     statement,
#    1599     distilled_parameters,
#    1600     execution_options,
#    1601     statement,
#    1602     distilled_parameters,
#    1603 )
#    1605 if not future:
#    1606     if self._has_events or self.engine._has_events:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1859             branched.close()
#    1861 except BaseException as e:
# -> 1862     self._handle_dbapi_exception(
#    1863         e, statement, parameters, cursor, context
#    1864     )
#    1866 return result
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2041     util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2042 elif should_wrap:
# -> 2043     util.raise_(
#    2044         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2045     )
#    2046 else:
#    2047     util.raise_(exc_info[1], with_traceback=exc_info[2])
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/util/compat.py:208, in raise_(***failed resolving arguments***)
#     205     exception.__cause__ = replace_context
#     207 try:
# --> 208     raise exception
#     209 finally:
#     210     # credit to
#     211     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     212     # as the __traceback__ object creates a cycle
#     213     del exception, replace_context, from_, with_traceback
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1817                 break
#    1818     if not evt_handled:
# -> 1819         self.dialect.do_execute(
#    1820             cursor, statement, parameters, context
#    1821         )
#    1823 if self._has_events or self.engine._has_events:
#    1824     self.dispatch.after_cursor_execute(
#    1825         self,
#    1826         cursor,
#    (...)
#    1830         context.executemany,
#    1831     )
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/sqlalchemy/engine/default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     731 def do_execute(self, cursor, statement, parameters, context=None):
# --> 732     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.UndefinedTable) relation "flights_group_x_rr" does not exist
# LINE 3:             FROM flights_group_x_rr;
#                          ^
#
# [SQL:
#             SELECT origin
#             FROM flights_group_x_rr;
# ]
# (Background on this error at: https://sqlalche.me/e/14/f405)

# %%
import pandas as pd

# Assuming you have already loaded your data into a DataFrame called df_flights_2010_2

# Define the list of selected airports
selected_airports = ['DCA', 'IAD', 'BWI', 'PHL', 'EWR', 'JFK', 'LGA']

# Filter the DataFrame to include only the selected airports
df_selected_airports = df_flights_2010_2[df_flights_2010_2['origin'].isin(selected_airports)]

# Group by 'origin' and count the number of flights for each airport
departure_count = df_selected_airports.groupby('origin')['flight_number'].count().reset_index()
departure_count.columns = ['origin', 'departure_count']

# Calculate airport rank based on departure count
departure_count['airport_rank'] = departure_count['departure_count'].rank(ascending=False).astype(int)

# Sort the result by departure count in descending order
departure_count = departure_count.sort_values('departure_count', ascending=False)

# Reset index for display
departure_count = departure_count.reset_index(drop=True)

print(departure_count)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'origin'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 9
#       6 selected_airports = ['DCA', 'IAD', 'BWI', 'PHL', 'EWR', 'JFK', 'LGA']
#       8 # Filter the DataFrame to include only the selected airports
# ----> 9 df_selected_airports = df_flights_2010_2[df_flights_2010_2['origin'].isin(selected_airports)]
#      11 # Group by 'origin' and count the number of flights for each airport
#      12 departure_count = df_selected_airports.groupby('origin')['flight_number'].count().reset_index()
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File /opt/homebrew/Caskroom/miniconda/base/envs/nf_sql/lib/python3.9/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'origin'

# %%
#Get to count of flights and cancellation rate from my flights_df

import pandas as pd

# Assuming you have already loaded your data into a DataFrame called flights_df

# Define the list of origin values
origin_values = ['DCA', 'IAD', 'BWI', 'PHL', 'EWR', 'JFK', 'LGA']

# Filter the DataFrame to include only the specified origin values
df_selected_airports = df_selected_airports[df_selected_airports['origin'].isin(origin_values)]

# Extract year from flight_date
df_selected_airports['year'] = df_selected_airports['flight_date'].dt.year

# Calculate flight count and cancellation rate grouped by 'year' and 'origin'
result_df = df_selected_airports.groupby(['year', 'origin']).agg(
    flight_count=('flight_date', 'size'),
    cancellation_rate=('cancelled', lambda x: round((x.sum() / len(x)) * 100, 2))
).reset_index()

# Sort the result by 'year' and 'origin'
result_df = result_df.sort_values(['year', 'origin'])

# Set 'year' and 'origin' as indexes
result_df.set_index(['year', 'origin'], inplace=True)

result_df
# Out:
#              flight_count  cancellation_rate
# year origin
# 2010 BWI             7344              19.40
#      DCA             5959              22.76
#      EWR             8724              13.39
#      IAD             5444              17.82
#      JFK             8901               9.79
#      LGA             7449              14.36
#      PHL             6576              15.75
# 2011 BWI             7410               3.66
#      DCA             6100               6.67
#      EWR             8216               9.01
#      IAD             6064               4.70
#      JFK             7003               4.71
#      LGA             7647               8.67
#      PHL             6459               4.29
# 2012 BWI             7675               0.59
#      DCA             5354               1.08
#      EWR             8831               1.22
#      IAD             5605               1.23
#      JFK             7319               0.33
#      LGA             7515               1.48
#      PHL             6110               0.41
# 2013 BWI             7301               2.04
#      DCA             5835               3.74
#      EWR             9107               5.60
#      IAD             5336               2.55
#      JFK             8421               4.69
#      LGA             7423               5.12
#      PHL             6266               1.92
# 2014 BWI             6570               6.88
#      DCA             5357               9.48
#      EWR             8541              15.14
#      IAD             4215              11.20
#      JFK             7265               6.47
#      LGA             7914              13.72
#      PHL             5549               7.73
# 2015 BWI             6236               5.37
#      DCA             6229               9.01
#      EWR             8070               7.63
#      IAD             3001               4.77
#      JFK             7740               6.24
#      LGA             8945              11.94
#      PHL             5207               4.61
# 2016 BWI             6685               2.69
#      DCA             6193               4.51
#      EWR             8522               3.53
#      IAD             2241               1.43
#      JFK             7672               1.49
#      LGA             7879               5.70
#      PHL             5377               1.45
# 2017 BWI             6763               1.57
#      DCA             5703               2.24
#      EWR             8323               4.36
#      IAD             2276               0.79
#      JFK             7186               3.84
#      LGA             6923               5.11
#      PHL             5205               1.94

# %%
#Check highest cancellation rates: 
result_df.sort_values('cancellation_rate', ascending=False)
# Out:
#              flight_count  cancellation_rate
# year origin
# 2010 DCA             5959              22.76
#      BWI             7344              19.40
#      IAD             5444              17.82
#      PHL             6576              15.75
# 2014 EWR             8541              15.14
# 2010 LGA             7449              14.36
# 2014 LGA             7914              13.72
# 2010 EWR             8724              13.39
# 2015 LGA             8945              11.94
# 2014 IAD             4215              11.20
# 2010 JFK             8901               9.79
# 2014 DCA             5357               9.48
# 2015 DCA             6229               9.01
# 2011 EWR             8216               9.01
#      LGA             7647               8.67
# 2014 PHL             5549               7.73
# 2015 EWR             8070               7.63
# 2014 BWI             6570               6.88
# 2011 DCA             6100               6.67
# 2014 JFK             7265               6.47
# 2015 JFK             7740               6.24
# 2016 LGA             7879               5.70
# 2013 EWR             9107               5.60
# 2015 BWI             6236               5.37
# 2013 LGA             7423               5.12
# 2017 LGA             6923               5.11
# 2015 IAD             3001               4.77
# 2011 JFK             7003               4.71
#      IAD             6064               4.70
# 2013 JFK             8421               4.69
# 2015 PHL             5207               4.61
# 2016 DCA             6193               4.51
# 2017 EWR             8323               4.36
# 2011 PHL             6459               4.29
# 2017 JFK             7186               3.84
# 2013 DCA             5835               3.74
# 2011 BWI             7410               3.66
# 2016 EWR             8522               3.53
#      BWI             6685               2.69
# 2013 IAD             5336               2.55
# 2017 DCA             5703               2.24
# 2013 BWI             7301               2.04
# 2017 PHL             5205               1.94
# 2013 PHL             6266               1.92
# 2017 BWI             6763               1.57
# 2016 JFK             7672               1.49
# 2012 LGA             7515               1.48
# 2016 PHL             5377               1.45
#      IAD             2241               1.43
# 2012 IAD             5605               1.23
#      EWR             8831               1.22
#      DCA             5354               1.08
# 2017 IAD             2276               0.79
# 2012 BWI             7675               0.59
#      PHL             6110               0.41
#      JFK             7319               0.33

# %%
import pandas as pd

# Assuming you have already loaded your data into a DataFrame called flights_df

# Extract year from flight_date
df_selected_airports['year'] = df_selected_airports['flight_date'].dt.year

# Calculate flight count and cancellation rate
result_df = df_selected_airports.groupby('year').agg(
    flight_count=('flight_date', 'size'),
    cancellation_rate=('cancelled', lambda x: round((x.sum() / len(x)) * 100, 2))
).reset_index()

# Sort the result by year
result_df = result_df.sort_values('year')

print(result_df)
# Out:
#    year  flight_count  cancellation_rate
# 0  2010         50397              15.67
# 1  2011         48899               6.08
# 2  2012         48409               0.91
# 3  2013         49689               3.84
# 4  2014         45411              10.37
# 5  2015         45428               7.59
# 6  2016         44569               3.22
# 7  2017         42379               3.18

# %% [markdown]
# Plotting Results:

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already loaded your data into a DataFrame called df_selected_airports
# Extract year from flight_date
df_selected_airports['year'] = df_selected_airports['flight_date'].dt.year

# Calculate flight count and cancellation rate
result_df = df_selected_airports.groupby('year').agg(
    flight_count=('flight_date', 'size'),
    cancellation_rate=('cancelled', lambda x: round((x.sum() / len(x)) * 100, 2)),
    flight_cancelled_count=('cancelled', 'sum')  # Summing up cancelled flights
).reset_index()

# Sort the result by year
result_df = result_df.sort_values('year')

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Stacking flight count and cancelled flight count
ax1.bar(result_df['year'], result_df['flight_count'], color='skyblue', label='Flight Count')
ax1.bar(result_df['year'], result_df['flight_cancelled_count'], color='salmon', label='Cancelled Flight Count', bottom=result_df['flight_count'])

# Adding data labels for flight count and cancelled flight count
for i, v in enumerate(result_df['flight_count']):
    ax1.text(result_df['year'][i], v + result_df['flight_cancelled_count'][i] / 2, str(v), color='black', ha='center', va='bottom')
    ax1.text(result_df['year'][i], v / 2, str(result_df['flight_cancelled_count'][i]), color='black', ha='center', va='bottom')

# Setting title and labels
plt.title('Count of Flights in February Across 2010-2017')
ax1.set_xlabel('Year')
ax1.set_ylabel('Flight Count')
ax1.tick_params(axis='y')

# Adding legend
plt.legend()

# Show plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have already loaded your data into a DataFrame called df_selected_airports
# Extract year from flight_date
df_selected_airports['year'] = df_selected_airports['flight_date'].dt.year

# Calculate flight count and cancellation rate
result_df = df_selected_airports.groupby('year').agg(
    flight_count=('flight_date', 'size'),
    cancellation_rate=('cancelled', lambda x: round((x.sum() / len(x)) * 100, 2)),
    flight_cancelled_count=('cancelled', 'sum')  # Summing up cancelled flights
).reset_index()

# Sort the result by year
result_df = result_df.sort_values('year')

# Plotting
fig, ax1 = plt.subplots(figsize=(10, 6))

# Stacking flight count and cancelled flight count
ax1.bar(result_df['year'], result_df['flight_count'], color='skyblue', label='Flight Count')
ax1.bar(result_df['year'], result_df['flight_cancelled_count'], color='salmon', label='Cancelled Flight Count', bottom=result_df['flight_count'])

# Adding data labels for flight count and cancelled flight count
for i, v in enumerate(result_df['flight_count']):
    ax1.text(result_df['year'][i], v + result_df['flight_cancelled_count'][i] / 2, str(v), color='black', ha='center', va='bottom')
    ax1.text(result_df['year'][i], v / 2, str(result_df['flight_cancelled_count'][i]), color='black', ha='center', va='bottom')

# Setting title and labels
plt.title('Count of Flights in February Across 2010-2017')
ax1.set_xlabel('Year')
ax1.set_ylabel('Flight Count')
ax1.tick_params(axis='y')

# Adding secondary y-axis for cancellation rate
ax2 = ax1.twinx()
ax2.plot(result_df['year'], result_df['cancellation_rate'], color='orange', label='Cancellation Rate (%)', marker='o')
ax2.set_ylabel('Cancellation Rate (%)')

# Adding data labels for cancellation rate
for i, v in enumerate(result_df['cancellation_rate']):
    ax2.text(result_df['year'][i], v, f'{v}%', color='black', ha='center', va='bottom')

# Adding legend
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc='upper left', bbox_to_anchor=(1, 1))

# Show plot
plt.show()

# %% [markdown]
# Performing statistical test:

# %%
import pandas as pd
from scipy.stats import ttest_ind, mannwhitneyu

# Sample DataFrame (replace this with your actual DataFrame)
data = {
    'year': [2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017],
    'cancellation_rate': [15.67, 6.08, 0.91, 3.84, 10.37, 7.59, 3.22, 3.18]
}
result_df = pd.DataFrame(data)

# Define cancellation rates for 2010 and other years
cancellation_rate_2010 = result_df[result_df['year'] == 2010]['cancellation_rate']
other_years_cancellation_rate = result_df[result_df['year'] != 2010]['cancellation_rate']

# Perform two-sample t-test
t_stat, t_pval = ttest_ind(cancellation_rate_2010, other_years_cancellation_rate)

# Perform Mann-Whitney U test
mwu_stat, mwu_pval = mannwhitneyu(cancellation_rate_2010, other_years_cancellation_rate)

# Print results
print("Two-Sample t-test:")
print(f"t-statistic: {t_stat}")
print(f"p-value: {t_pval}")
print("\nMann-Whitney U test:")
print(f"U-statistic: {mwu_stat}")
print(f"p-value: {mwu_pval}")
# Out:
# Two-Sample t-test:
# t-statistic: 3.1156362992966242
# p-value: 0.020699633802560197
#
# Mann-Whitney U test:
# U-statistic: 7.0
# p-value: 0.25

# %% [markdown]
# Ordering results by airport, to narrow down outliers

# %%
import pandas as pd

# Assuming you have already loaded your data into a DataFrame called flights_df

# Extract year from flight_date
df_selected_airports['year'] = df_selected_airports['flight_date'].dt.year

# Calculate flight count and cancellation rate grouped by 'origin'
result_df = df_selected_airports.groupby(['origin', 'year']).agg(
    flight_count=('flight_date', 'size'),
    cancellation_rate=('cancelled', lambda x: round((x.sum() / len(x)) * 100, 2))
).reset_index()

# Sort the result by 'origin' and 'year'
result_df = result_df.sort_values(['origin', 'year'])

result_df
# Out:
#    origin  year  flight_count  cancellation_rate
# 0     BWI  2010          7344              19.40
# 1     BWI  2011          7410               3.66
# 2     BWI  2012          7675               0.59
# 3     BWI  2013          7301               2.04
# 4     BWI  2014          6570               6.88
# 5     BWI  2015          6236               5.37
# 6     BWI  2016          6685               2.69
# 7     BWI  2017          6763               1.57
# 8     DCA  2010          5959              22.76
# 9     DCA  2011          6100               6.67
# 10    DCA  2012          5354               1.08
# 11    DCA  2013          5835               3.74
# 12    DCA  2014          5357               9.48
# 13    DCA  2015          6229               9.01
# 14    DCA  2016          6193               4.51
# 15    DCA  2017          5703               2.24
# 16    EWR  2010          8724              13.39
# 17    EWR  2011          8216               9.01
# 18    EWR  2012          8831               1.22
# 19    EWR  2013          9107               5.60
# 20    EWR  2014          8541              15.14
# 21    EWR  2015          8070               7.63
# 22    EWR  2016          8522               3.53
# 23    EWR  2017          8323               4.36
# 24    IAD  2010          5444              17.82
# 25    IAD  2011          6064               4.70
# 26    IAD  2012          5605               1.23
# 27    IAD  2013          5336               2.55
# 28    IAD  2014          4215              11.20
# 29    IAD  2015          3001               4.77
# 30    IAD  2016          2241               1.43
# 31    IAD  2017          2276               0.79
# 32    JFK  2010          8901               9.79
# 33    JFK  2011          7003               4.71
# 34    JFK  2012          7319               0.33
# 35    JFK  2013          8421               4.69
# 36    JFK  2014          7265               6.47
# 37    JFK  2015          7740               6.24
# 38    JFK  2016          7672               1.49
# 39    JFK  2017          7186               3.84
# 40    LGA  2010          7449              14.36
# 41    LGA  2011          7647               8.67
# 42    LGA  2012          7515               1.48
# 43    LGA  2013          7423               5.12
# 44    LGA  2014          7914              13.72
# 45    LGA  2015          8945              11.94
# 46    LGA  2016          7879               5.70
# 47    LGA  2017          6923               5.11
# 48    PHL  2010          6576              15.75
# 49    PHL  2011          6459               4.29
# 50    PHL  2012          6110               0.41
# 51    PHL  2013          6266               1.92
# 52    PHL  2014          5549               7.73
# 53    PHL  2015          5207               4.61
# 54    PHL  2016          5377               1.45
# 55    PHL  2017          5205               1.94

# %% [markdown]
# Initial plots

# %%
import matplotlib.pyplot as plt

# Plotting flight count
plt.figure(figsize=(8, 3))
bars = plt.bar(result_df['year'], result_df['flight_count'], color='skyblue')
plt.xlabel('Year')
plt.ylabel('Flight Count')
plt.title('Flight Count in February Across Years (2010-2017)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(result_df['year'])  # Ensure all years are shown on the x-axis

# Adding data labels for flight count
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), 
             round(bar.get_height(), 2), ha='center', va='bottom')

plt.show()

# Plotting cancellation rate
plt.figure(figsize=(8, 3))
bars = plt.bar(result_df['year'], result_df['cancellation_rate'], color='salmon')
plt.xlabel('Year')
plt.ylabel('Cancellation Rate (%)')
plt.title('Cancellation Rate in February Across Years (2010-2017)')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.xticks(result_df['year'])  # Ensure all years are shown on the x-axis

# Adding data labels for cancellation rate
for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), 
             f"{round(bar.get_height(), 2)}%", ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt

# Create figure and axis objects
fig, ax1 = plt.subplots(figsize=(8, 3))

# Plot flight count on primary axis
color = 'skyblue'
ax1.set_xlabel('Year')
ax1.set_ylabel('Flight Count', color=color)
ax1.bar(result_df['year'], result_df['flight_count'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

# Create secondary axis for cancellation rate
ax2 = ax1.twinx()  
color = 'salmon'
ax2.set_ylabel('Cancellation Rate (%)', color=color)
ax2.plot(result_df['year'], result_df['cancellation_rate'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)

# Add percentage value labels for cancellation rate
for i, rate in enumerate(result_df['cancellation_rate']):
    ax2.text(result_df['year'][i], rate, f'{rate}%', ha='center', va='bottom', fontsize=8, color=color)

# Title and grid
plt.title('Flight Count and Cancellation Rate in February Across Years (2010-2017)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %%
from sql_functions import get_data

# %%
schema = 'hh_analytics_24_1'
sql_query_1 = f"""
    SELECT DATE_PART('year', flight_date) AS year,
    COUNT(*) AS flight_count,
    ROUND(AVG(cancelled::int) * 100, 2) AS cancellation_rate
    FROM {schema}.flights_2010_to_2017
    GROUP BY DATE_PART('year', flight_date)
    ORDER BY year;
"""
#sql_query_1
get_dataframe(sql_query_1)
# Out:
#      year  flight_count  cancellation_rate
# 0  2010.0         97513              15.25
# 1  2011.0         95174               5.92
# 2  2012.0         93747               0.87
# 3  2013.0         95879               3.75
# 4  2014.0         88303              10.17
# 5  2015.0         88806               7.40
# 6  2016.0         87537               3.08
# 7  2017.0         83580               3.11
